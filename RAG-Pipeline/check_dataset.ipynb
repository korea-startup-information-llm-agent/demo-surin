# %% [markdown]
# # 국가중점기술 대응 특허 데이터셋
# - IPC (International Patent Classification): 국제특허분류
#   - 구조: Section, Class, Subclass, MainGroup, SubGroup
#   ```plain text
#   // Section: IPC 계층 구조의 가장 상위 레벨
#   - A: 생활필수품
#   - B: 처리조작; 운수
#   - C: 화학; 야금
#   - D: 섬유; 지류
#   - E: 고정구조물
#   - F: 기계공학; 조명; 가열; 무기; 폭파
#   - G: 물리학
#   - H: 전기
#
#   // Class: Section을 세분화
#   - Class 기호: Section 기호에 2개의 숫자를 붙인 것.
#
#   // Subclass: 각 클래스는 1개 이상의 서브 클래스를 포함한다.
#   - Subclass 기호: 클래스 기호에 1개의 대문자를 붙인 것.
#
#   // MainGroup: 발명의 검색에 유용하다고 생각되는 주제사항의 분야를 나타내는 것
#   - MainGroup 기호: 1~3개의 숫자로 구성, 사선(/)과 숫자 00을 뒤에 붙인다.
#
#   // SubGroup: MainGroup 밑에 세부전개항목을 형성하는 것
#   - SubGroup 기호: 메인그룹 및 사선 이후에 00 이외의 적어도 2개의 숫자를 붙인 것.
#   - SubGroup 타이틀: MainGroup의 분류범위 내에서 발명의 서치에 유용하다고 생각되는 주제사항의 분야.
#   ```
#
#
# ## 데이터셋 구성
#
# ### raw:
#
#   ```json
#   {
#     "dataset": {
#       "updateDate": "업데이트년도월일",
#       "Stext": "소분류설명",
#       "Mtext": "중분류설명",
#       "Ltext": "대분류설명",
#       "Sno": "소분류코드",
#       "Mno": "중분류코드",
#       "Lno": "대분류코드",
#       "ipc_main": "메인 IPC",
#       "country_code": "국가코드",
#       "documentId": "문헌키",
#       "document_type": "문헌타입(문헌키 맨뒤에 알파벳 + 숫자)" ,
#       "application_number": "출원번호",
#       "keyword": "키워드6개 & 대분류 1개",
#     }
#   }
#   ```
#
# ### label:
#
#   ```json
#   {
#     "dataset": {
#       "application_year": "출원연도",
#       "application_date": "출원일자",
#       "documentId": "문헌키",
#       "application_number": "출원번호",
#     }
#   }
#   ```

# %%
import os

# 데이터셋 메인 폴더명
dataset_path = "/Users/ssr/Documents/startup-chatbot-surin/RAG-Pipeline/dataset"

raw_dataset_folder = os.path.join(dataset_path, "raw")
label_dataset_folder = os.path.join(dataset_path, "label")

# %% [markdown]
# ## RAW 데이터셋 확인

# %%
# RAW 데이터셋 확인하기
# zip 파일 압축 풀기
import zipfile
import json

for zip_file in os.listdir(raw_dataset_folder):
    
    zip_file_path = os.path.join(raw_dataset_folder, zip_file)
    print(zip_file_path)
    middle_code = zip_file_path.split("_")[7]
    print("국가중점기술분류 중분류코드:", middle_code)

    with zipfile.ZipFile(zip_file_path, "r") as raw_zip_file:
        json_files = [
            file_name
            for file_name in raw_zip_file.namelist()
            if file_name.endswith(".json")
        ]
        print("현재 ZIP 폴더 총 파일 개수:", len(raw_zip_file.namelist()))
        print("현재 ZIP 폴더 JSON 파일 개수:", len(json_files))
        print(json_files[:5])
        print("예시 JSON 파일 내용:")

        with raw_zip_file.open(json_files[0], "r") as example:
            json_example = example.read().decode("utf-8")
        
        data = json.loads(json_example)
        print(json.dumps(data, indent=4, ensure_ascii=False))
        print()
# Out:
# /Users/ssr/Documents/startup-chatbot-surin/dataset/raw/TS_C_ICT_SW_CC_빅데이터_인공지능_CCC_다중인공지능공통플랫폼기술.zip
# 국가중점기술분류 중분류코드: CCC
# 현재 ZIP 폴더 총 파일 개수: 3641
# 현재 ZIP 폴더 JSON 파일 개수: 3641
# ['/jp2002578212a.json', '/jp2002313500a.json', '/jp2019028834b1.json', '/jp2001508777a.json', '/jp2008336140a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2002",
#         "invention_title": "인공지능 애플리케이션을 위한 음례를 선택하는 적응형 샘플링 수법",
#         "ipc_section": "G",
#         "abstract": "인공지능 애플리케이션은 정례 및 음례를 포함한 훈련 세트한 이용을 필요로 한다. 음례는 특징 공간에서 우위인 특징에 관해서 정례의 분포를 이용하여 선택된다. 음례는 특징 공간에서 우위인 특징의 값을 상기 정례와 공유하는 또는 대략 공유한다. 이 타입의 훈련 세트가, 콘텐트리코멘다, 특히 텔레비젼 프로그램에 대한 리코멘다에 관해서 설명된다.",
#         "ipc_subclass": "G06N",
#         "applicant_name": "코닌크렉카 필립스 엘렉트로닉스 N 비",
#         "ipc_main": "G06N-005/04",
#         "ipc_all": "G06N-005/04",
#         "ipc_class": "G06",
#         "claims": "정례 및 음례를 가지는 훈련 세트한 이용을 필요로 하는 인공지능 애플리케이션을 실행하도록 구성된 처리 장치로서,데이터 및/또는 명령을 저장하도록 구성된 적어도 1개의 메모리와,상기 적어도 1개의 메모리를 이용하여, 훈련을 위한 정례 세트를 인식해 유지하는 조작, 및 상기 정례 세트에 따라 훈련을 위한 음례 세트를 선택하는 조작을 실행하도록 구성된 적어도 1개의 프로세서와,를 가지는 처리 장치.정례 및 음례를 가지는 훈련 세트한 이용을 필요로 하는, 콘텐츠를 추천하는 방법으로서,훈련을 위한 정례 세트를 인식해 유지하는 단계와,상기 정례 세트에 따라 훈련을 위한 음례 세트를 선택하는 단계와,를 가지는 방법.컴퓨터 프로그램으로서, 상기 컴퓨터 프로그램을 실행했을 때에, 프로그램 가능인 기기가 청구항 1 내지 8의 어느 한 항에 기재된 장치로서 기능하는 것을 가능하게 하는 컴퓨터 프로그램.",
#         "application_date": "20020325",
#         "documentId": "jp2002578212a",
#         "application_number": "2002-578212"
#     }
# }
#
# /Users/ssr/Documents/startup-chatbot-surin/dataset/raw/TS_C_ICT_SW_CD_컴퓨팅_소프트웨어_CDB_신개념컴퓨팅기술.zip
# 국가중점기술분류 중분류코드: CDB
# 현재 ZIP 폴더 총 파일 개수: 3455
# 현재 ZIP 폴더 JSON 파일 개수: 3455
# ['/jp2008527187b2.json', '/jp2012526898b2.json', '/jp2015560404a.json', '/jp2005171364b2.json', '/jp2005013318b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "open_date": "20090205",
#         "application_year": "2006",
#         "invention_title": "사용자에게 관심을 당기는 아이템을 추천하는 시스템 및 방법",
#         "ipc_section": "G",
#         "open_number": "2009-505298",
#         "register_date": "20120706",
#         "abstract": "클러스터화 디시젼트리와 빈도 베이스의 용어 매핑과의 조합을 이용해, 개개의 사용자에게 아이템을 추천하는 시스템 및 방법을 개시한다. 시스템 및 방법은 텔레비젼 리모트 콘트롤 활동이나 컴퓨터 키보드 입력 등의 사용자 동작에 근거하는 데이터를 받도록 구성되어 새로운 아이템 데이터가, 텔레비젼 프로그램 가이드, 영화 데이터베이스, 광고 데이터의 전달자, 온라인 옥션 웹사이트, 전자 메일 서버 등의 소스로부터 사용 가능하게 되었을 때에, 시스템 및 방법은 새로운 아이템 데이터를 해석적으로 분해하고, 그것을, 과거에 사용자가 좋아한 아이템 데이터의 확인된 속성과 비교하고, 새로운 아이템 데이터의 수치 랭킹을 동적으로 생성한 것으로, 이것은 후속한 유저 입력이나 아이템 데이터 전달자에 의한 데이터 조작없이 이루어지고 또한, 각각의 사용자에 대해서 조정되는 것이다. 사용자 동작에 근거하여 사용자의 관심을 학습하고, 이어서, 학습한 지식을 적용해, 사용자의 관심의 레벨에 근거하여, E메일스팸메일 등의 아이템을 순위를 매겨 추천, 및/또는 필터링하는 실시 형태가 개시된다. 실시 형태는 텔레비젼 프로그램, 웹 기반의 옥션, 타겟 광고, 전자 메일 필터링 등의 응용예로, 자동식의 개인용의 정보학습, 추천, 및/또는 필터링한 시스템에 대해서 사용할 수 있다. 실시 형태는 아이템 설명을 생성하고, 관심이 있는 아이템을 학습하고, 아이템을 효과적으로 기술하는 용어를 학습하고, 유사한 아이템을 컴팩트한 데이터 구조로 클러스터화 하고, 이어서 그 구조를 이용해 새로운 제공물을 순위를 매겨 하도록, 구축할 수 있다. 본 발명의 실시 형태는 비한정적인 예로서 어느 후보 아이템을 다른 후보 아이템으로 우선해 추천할 수 있도록 후보 아이템으로의 런크스 코어의 할당을 가능하게 하는 능력과, 감독 없음 학습을 사용해 디시젼트리를 증강형으로 구축하고, 「에지」(세련클라이언트) 컴퓨팅과 정합시켜, 예를 카테고리로 자동적으로 클러스터화 하고, 그에 따라 몇개의 데이터 구조와 처리의 대부분이 셋탑박스 또는 로컬 PC에 국소화 되도록 하는 능력과, 콘텐츠 속성을 자동적으로 온 더 플라이로 학습하는 능력과, 유저 선호를 불투명한 로컬데이터 구조로 저장하고, 유저 선호가 개개의 사용자에게 쉽게는 트레이스 할 수 없게 하는 능력을 포함한다.",
#         "ipc_subclass": "G06F",
#         "applicant_name": "포스 월미디어인코퍼레이티드",
#         "ipc_main": "G06F-017/30",
#         "register_year": "2012",
#         "ipc_all": "G06F-017/30",
#         "ipc_class": "G06",
#         "claims": "계산 시스템이 적어도 1개의 처리 수단을 사용해 사용자에게 아이템을 추천하는 방법으로서, 상기 처리 수단에 의해 행해진다 1또는 복수의 데이터소스로부터 아이템 설명을 꺼내는 단계와, 상기 아이템 설명을, 속성 비트·벡터 및 1또는 복수의 용어 번호를 포함한 바이너리 속성 포맷으로 변환하는 단계로서, 상기 속성 비트·벡터는 상기 아이템을 설명하는 속성의 고정된 세트를 포함하고, 상기 용어 번호는 상기 아이템을 설명하는 속성의 가변한 세트를 포함한, 단계와, 상기 아이템 설명을, 상기 바이너리 속성 포맷으로부터 비트벡터로 변환하는 단계로서, 상기 비트벡터는 상기 속성 비트·벡터에 포함되는 정보와, 용어 매핑프로세스에 의해 결정되는 상기 용어 번호에 의해 정해지는 정보의 부분집합을 포함한 용어 비트벡터를 포함한, 단계와, 사용자액션을 감시함으로써, 사용자의 관심을 당기는 아이템을 식별하는 단계와, 1또는 복수의 기계 학습 기법을 사용해, 사용자의 관심을 당기는 아이템을 인식하는 것을 학습하는 단계로서, 관심을 당기는 상기 아이템을 나타내는 상기 비트벡터는 상기 기계 학습 기법으로의 입력으로 여겨지는, 단계와,1이상의 상기 아이템의 상기 비트벡터와, 상기 기계 학습 기법에 의해 결정되어 부호화된 유사하는 아이템이 관련하는 값을 비교함으로써 계산한 랭킹스코어에 근거하여, 1조의 아이템으로부터 1또는 복수의 아이템을 추천하는 단계와 (을)를 구비하는 방법. 청구항 8에 기재된 방법으로서, 복수의 유저간에서의 구별을 실시하기 위해서 복수의 클러스터화 디시젼트리가 사용되는, 방법 사용자에게 아이템을 추천하는 시스템으로서,1이상의 처리 수단을 구비하고, 상기 처리 수단은 1또는 복수의 데이터소스로부터 아이템 설명을 꺼내는 처리와, 상기 아이템 설명을, 속성 비트·벡터 및 1또는 복수의 용어 번호를 포함한 바이너리 속성 포맷으로 변환하는 처리로서, 상기 속성 비트·벡터는 상기 아이템을 설명하는 속성의 고정된 세트를 포함하고, 상기 용어 번호는 상기 아이템을 설명하는 속성의 가변한 세트를 포함하는 것이는, 처리와, 상기 아이템 설명을 상기 바이너리 속성 포맷으로부터 비트벡터로 변환하는 처리로서, 상기 비트벡터는 상기 속성 비트·벡터에 포함되는 정보와, 용어 매핑프로세스에 의해 결정되는 상기 용어 번호에 의해 정해지는 정보의 부분집합을 포함한 용어 비트벡터를 포함하는 것이는, 처리와,사용자의 관심을 당기는 아이템을 식별하는 처리와, 1또는 복수의 기계 학습 기법을 사용해, 사용자의 관심을 당기는 아이템을 인식하는 것을 학습하는 처리로서, 관심을 당기는 상기 아이템을 나타내는 상기 비트벡터는 상기 기계 학습 기법으로의 입력으로 여겨지는 것이는, 처리와,1이상의 상기 아이템의 상기 비트벡터와, 상기 기계 학습 기법에 의해 결정되어 부호화된 유사하는 아이템이 관련하는 값을 비교함으로써 계산한 랭킹스코어에 근거하여, 1조의 아이템으로부터 1또는 복수의 아이템을 추천하는 처리와 (을)를 실시하는 구성을 구비하는 처리 수단이는, 시스템.",
#         "application_date": "20060821",
#         "register_number": "5032477",
#         "documentId": "jp2008527187b2",
#         "application_number": "2008-527187",
#         "open_year": "2009"
#     }
# }
#
# /Users/ssr/Documents/startup-chatbot-surin/dataset/raw/TS_C_ICT_SW_CD_컴퓨팅_소프트웨어_CDC_시스템SW운영및기반기술.zip
# 국가중점기술분류 중분류코드: CDC
# 현재 ZIP 폴더 총 파일 개수: 3588
# 현재 ZIP 폴더 JSON 파일 개수: 3588
# ['/jp2015043323b2.json', '/jp2016205574b2.json', '/jp2014101507a.json', '/jp2014236256b2.json', '/jp2014110103b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "open_date": "20150702",
#         "application_year": "2015",
#         "invention_title": "소프트웨어 애플리케이션 전달 및 기동 시스템",
#         "ipc_section": "G",
#         "open_number": "2015-122115",
#         "register_date": "20160415",
#         "abstract": "(과제) 클라이언트로 소프트웨어의 어느 부분도 인스톨 다투지 않고 , 서버로부터 클라이언트로 컴퓨터 통신망 경유로, 클라이언트로 실행하기 위한 컴퓨터 소프트웨어를 배치한다. (해결수단) 제1의 가상 메모리를 할당할 단계(104)와, 소프트웨어의 제1의 부분의 실행가능인 코드를 수신할 단계와, 소프트웨어의 제1의 부분의 실행가능인 코드를 제1의 가상 메모리로 직접 기입할 단계(106)와, 제1의 가상 메모리를 실행가능으로서 마크할 단계와, 소프트웨어의 제1의 부분을 1의 가상 메모리로부터 직접 실행할 단계(112)와, 소프트웨어의 제1의 부분의 실행가능인 코드가 재촉한 소프트웨어의 제2의 부분의 실행가능인 코드를 다운로드해 실행할 단계(114)를 실행한다. (선택도) 도 1.",
#         "ipc_subclass": "G06F",
#         "applicant_name": "알 바흐, 쥬리안, 마이클",
#         "ipc_main": "G06F-009/445",
#         "register_year": "2016",
#         "ipc_all": "G06F-009/445",
#         "ipc_class": "G06",
#         "claims": "제1의 컴퓨팅 디바이스에 의해서 제1의 가상 메모리를 할당할 단계와, 상기 제 1의 컴퓨팅 디바이스에 의해서, 다른 컴퓨팅 시스템으로부터 통신 네트워크를 통해 그루터기의 실행가능인 코드를 수신할 단계와, 상기 제 1의 컴퓨팅 디바이스에 의하고, 상기 그루터기의 상기 실행가능인 코드를 상기 제 1의 가상 메모리로부터 직접 실행할 단계와, 상기 제 1의 컴퓨팅 디바이스에 의하고, 상기 그루터기의 상기 실행가능인 코드가 재촉한 소프트웨어의 제1의 부분(first piece of software)의 실행가능인 코드를 다운로드할 단계와, 상기 제 1의 컴퓨팅 디바이스에 의해서, 소프트웨어의 상기 제 1의 부분의 상기 실행가능인 코드를 실행할 단계와, 상기 제 1의 컴퓨팅 디바이스에 의해서, 소프트웨어의 상기 제 1의 부분의 상기 실행가능인 코드가 재촉한 소프트웨어의 제2의 부분(second piece of software)의 실행가능인 코드를 다운로드할 단계와, 상기 제 1의 컴퓨팅 디바이스에 의해서, 소프트웨어의 상기 제 2의 부분의 상기 실행가능인 코드를 실행할 단계와, 를 구비하는 방법. 1또는 복수의 프로세서에 의해 실행가능인 복수의 명령을 저장하는 메모리와, 상기 메모리에 접속된 1또는 복수의 프로세서와, 를 구비하고, 상기 메모리에 저장된 상기 복수의 명령은 상기 1또는 복수의 프로세서로, 제1의 가상 메모리를 할당할 단계와, 다른 컴퓨팅 시스템으로부터 통신 네트워크를 통해 그루터기의 실행가능인 코드를 수신할 단계와, 상기 그루터기의 상기 실행가능인 코드를 상기 제 1의 가상 메모리로부터 직접 실행할 단계와, 상기 그루터기의 상기 실행가능인 코드가 재촉한 소프트웨어의 제1의 부분(first piece of software)의 실행가능인 코드를 다운로드할 단계와, 소프트웨어의 상기 제 1의 부분의 상기 실행가능인 코드를 실행할 단계와, 소프트웨어의 상기 제 1의 부분의 상기 실행가능인 코드가 재촉한 소프트웨어의 제2의 부분(second piece of software)의 실행가능인 코드를 다운로드할 단계와, 소프트웨어의 상기 제 2의 부분의 상기 실행가능인 코드를 실행할 단계와, 를 실행시키기 위한 것인 시스템. 가상 메모리로부터 직접 실행되는 컴퓨터 프로그램으로서, 상기 컴퓨터 프로그램의 실행가능인 코드가 재촉한 소프트웨어의 제1의 부분(first piece of software)의 실행가능인 코드를 다운로드할 단계와, 소프트웨어의 상기 제 1의 부분의 상기 실행가능인 코드를 실행할 단계와, 소프트웨어의 상기 제 1의 부분의 상기 실행가능인 코드가 재촉한 소프트웨어의 제2의 부분(second piece of software)의 실행가능인 코드를 다운로드할 단계와, 소프트웨어의 상기 제 2의 부분의 상기 실행가능인 코드를 실행할 단계와, 를 컴퓨터로 실행시키는 복수의 명령을 구비하는 컴퓨터 프로그램.",
#         "application_date": "20150305",
#         "register_number": "5916002",
#         "documentId": "jp2015043323b2",
#         "application_number": "2015-043323",
#         "open_year": "2015"
#     }
# }
#
# /Users/ssr/Documents/startup-chatbot-surin/dataset/raw/TS_C_ICT_SW_CC_빅데이터_인공지능_CCB_초고속_대용량데이터플랫폼기술.zip
# 국가중점기술분류 중분류코드: CCB
# 현재 ZIP 폴더 총 파일 개수: 3453
# 현재 ZIP 폴더 JSON 파일 개수: 3453
# ['/jp2003406801a.json', '/jp2005158299b2.json', '/jp2005045280a.json', '/jp2001533509a.json', '/jp2001043585a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2003",
#         "invention_title": "코드 압축 기술의 고속 프로토타이핑을 가능하게 하는 프로그램한 코드 압축 방법, 및 코드 압축 시스템",
#         "ipc_section": "G",
#         "abstract": "(과제) 코드 압축 기술의 고속 프로토타이핑을 가능하게 하는 프로그램한 코드 압축 방법을 제공한다. (해결수단) 프로그램한 코드 압축을 위한 방법으로서, 해당 방법은 데이터로부터 코드를 분리하는 단계를 구비한다. 압축 공간과 비압축 공간의 사이에 주소매핑을 행하기 위한 소프트웨어 변환이, 코드로 도입된다. 명령한 출현 빈도에 관하는 통계가 취득되고, 상기 통계에는 2개가 연속하는 명령한 출현 빈도도 포함된다. 명령 또는 명령 페어의 출현을 식별하기 위해서, 프로그램이 해석된다. 식별된 명령은 압축 버스어 테이블을 나타내는 주소와 치환된다. 비압축 주소로부터 압축 주소로의 주소매핑이 생성된다. (선택도) 도 4.",
#         "ipc_subclass": "G06F",
#         "applicant_name": "일본 전기 주식회사",
#         "ipc_main": "G06F-012/04",
#         "ipc_all": "G06F-012/04|G06F-009/32|G06F-009/45|G06F-012/08",
#         "ipc_class": "G06",
#         "claims": "프로그램한 코드 압축을 위한 방법으로서, 해당 방법은 하기 단계를 구비한다. a) 데이터로부터 코드를 분리하는 단계. b) 압축 공간과 비압축 공간의 사이에 주소매핑을 행하기 위한 소프트웨어 변환을 코드로 도입하는 단계. c) 명령한 출현 빈도에 관하는 통계를 취득하는 단계로서, 상기 통계에는 2개가 연속하는 명령한 출현 빈도도 포함된다. d) 단계(c)에 포함되는 명령 또는 명령 페어의 출현을 식별하기 위해서, 프로그램을 해석한다. e) 단계(d)로 식별된 명령을, 압축 버스워드테이블을 나타내는 주소와 치환한다. f) 비압축 주소로부터 압축 주소로의 주소매핑을 생성한다. 프로그램한 코드 압축을 위한 방법으로서, 해당 방법은 하기 단계를 구비한다.a) 데이터로부터 코드를 분리하는 단계.b) 압축 공간과 비압축 공간의 사이에 주소매핑을 행하기 위한 소프트웨어 변환을 코드로 도입하는 단계.c) 워드의 출현 빈도에 관하는 통계를 취득하는 단계로서, 상기 통계에는 2개가 연속하는 워드의 출현 빈도도 포함된다.d) 단계(c)에 포함되는 워드 또는 워드페어의 출현을 식별하기 위해서, 프로그램을 해석한다.e) 단계(d)로 식별된 명령을, 압축 버스워드테이블을 나타내는 주소와 치환한다.f) 비압축 주소로부터 압축 주소로의 주소매핑을 생성한다. 프로그램한 코드 압축을 위한 시스템으로서, 해당 시스템은 하기 요건을 구비한다. 프로세서인터페이스와, 캐시와, 태그와, 외부 SRAM와, 압축 해제 엔진.",
#         "application_date": "20031205",
#         "documentId": "jp2003406801a",
#         "application_number": "2003-406801"
#     }
# }
#
# /Users/ssr/Documents/startup-chatbot-surin/dataset/raw/TS_C_ICT_SW_CD_컴퓨팅_소프트웨어_CDA_양자정보통신기술.zip
# 국가중점기술분류 중분류코드: CDA
# 현재 ZIP 폴더 총 파일 개수: 2031
# 현재 ZIP 폴더 JSON 파일 개수: 2031
# ['/jp2006163376b2.json', '/jp2002000785b2.json', '/jp2001081501a.json', '/jp2002059733a.json', '/jp2008203486b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "open_date": "20071227",
#         "application_year": "2006",
#         "invention_title": "양자 메모리 장치 및 통신 정보 설정 시스템",
#         "ipc_section": "H",
#         "open_number": "2007-335503",
#         "register_date": "20110722",
#         "abstract": "(과제) 단일 광자가 가지는 양자 정보를, 결합 양자도트(quantum dot)로부터의 발광이라고 하는 효율적인 과정을 통해 발광 후에 남은 결합 양자도트(quantum dot) 안의 2개의 전자 스핀으로 전사하고, 또한 그 정보를 2개의 전자 스핀에 의해서 쳐지는 안정인 부분 공간으로 저장한다. (해결수단) 전자 주입과 광여기에 의해, 결합 양자도트(quantum dot) 1, 2 내에, 전자 3개와 정공 1개를 생성한다. 이 상태는 양자도트(quantum dot) 1에 있어서 전자 1개와 정공 1개가 재결합해 발광하고, 광자가 1개 방출된 후, 양자도트(quantum dot) 1, 2 내에는 각각 1 개씩 전자가 남는다. 이 때, 양자도트(quantum dot)로부터 나오는 광자의 편광과, 결합 양자도트(quantum dot) 1, 2 내에 남은 2개의 전자의 스핀과의 사이에는, 양자 역학적 상관(엔탕르먼트)이 존재한다. 이 빛-전자간의 엔탕르먼트를 이용해, 양자 염력에 의한 이동이라고 하는 수법에 의해, 기억시키고 싶은 단일 광자의 편광 상태를 결합 양자도트(quantum dot) 1, 2 내의 전자 스핀 상태로 전사한다. (선택도) 도 1.",
#         "ipc_subclass": "H01L",
#         "applicant_name": "일본 전기 주식회사",
#         "ipc_main": "H01L-027/10",
#         "register_year": "2011",
#         "ipc_all": "H01L-027/10|H01L-029/06|H01L-029/66|H04L-009/12",
#         "ipc_class": "H01",
#         "claims": "입력광자의 편광 상태를 전자의 스핀 상태로 기억하는 양자 메모리 장치로서, 서로 결합된 2개의 양자도트(quantum dot)를 가지는 결합 양자도트(quantum dot)와, 상기 결합 양자도트(quantum dot)로 1개의 정공을 주입하고, 상기 결합 양자도트(quantum dot)의 한쪽의 양자도트(quantum dot)로 2개의 전자를 주입하고, 상기 결합 양자도트(quantum dot) 의 타방의 양자도트(quantum dot)로 1개의 전자를 주입하는 주입부와, 상기 한쪽의 양자도트(quantum dot)로 주입된 2개의 전자 중 어느 하나상기 1개의 정공과의 결합에서 발생하는 광자와, 상기 입력 광자와,의 사이의 벨 모양태를 판별함으로써, 상기 입력 광자의 편광 상태를, 각 양자도트(quantum dot)로 남은 전자의 스핀 상태로 전사하는 벨 모양태측정부를 포함한 양자 메모리 장치. 2살의 양자 메모리 장치와, 상기 2살의 양자 메모리 장치로 공유된 양자 상관을 상기 2살의 양자 메모리 장치로 기록하는 정보 기록 장치를 포함한 통신 정보 설정 시스템으로서, 상기 2살의 양자 메모리 장치의 각각은 서로 결합된 2개의 양자도트(quantum dot)를 가지는 결합 양자도트(quantum dot)와, 상기 결합 양자도트(quantum dot)로 1개의 정공을 주입하고, 상기 결합 양자도트(quantum dot)의 한쪽의 양자도트(quantum dot)로 2개의 전자를 주입하고, 상기 결합 양자도트(quantum dot) 의 타방의 양자도트(quantum dot)로 1개의 전자를 주입하는 주입부를 포함하고, 상기 정보 기록 장치는 각 결합 양자도트(quantum dot)로부터, 상기 한쪽의 양자도트(quantum dot) 안의 2개의 전자 중 어느 하나상기 1개의 정공과의 결합에서 발생하는 광자의 벨 모양태를 판정하고, 상기 공유된 양자 상관을, 각 양자도트(quantum dot)로 남은 전자의 스핀 상태로서 생성하는 벨 모양태측정부를 포함한, 통신 정보 설정 시스템. 서로 결합된 2개의 양자도트(quantum dot)를 가지는 결합 양자도트(quantum dot)와, 상기 결합 양자도트(quantum dot)로 1개의 정공을 주입하고, 상기 결합 양자도트(quantum dot)의 한쪽의 양자도트(quantum dot)로 2개의 전자를 주입하고, 상기 결합 양자도트(quantum dot) 의 타방의 양자도트(quantum dot)로 1개의 전자를 주입하고, 상기 결합 양자도트(quantum dot)로부터 상기 한쪽의 양자도트(quantum dot) 안의 2개의 전자 중 어느 하나상기 1개의 정공과의 결합에서 발생하는 광자와, 결합 양자도트(quantum dot)로 남은 전자와,의 사이에 양자 상관을 생성하는 주입부와, 상기 광자를 통신 상대로 전송하는 전송부를 포함한 통신 정보 설정 시스템.",
#         "application_date": "20060613",
#         "register_number": "4784751",
#         "documentId": "jp2006163376b2",
#         "application_number": "2006-163376",
#         "open_year": "2007"
#     }
# }
#
# /Users/ssr/Documents/startup-chatbot-surin/dataset/raw/TS_C_ICT_SW_CC_빅데이터_인공지능_CCA_지능형빅데이터분석및활용기술.zip
# 국가중점기술분류 중분류코드: CCA
# 현재 ZIP 폴더 총 파일 개수: 3480
# 현재 ZIP 폴더 JSON 파일 개수: 3480
# ['/jp2015120623a.json', '/jp2015160590b2.json', '/jp2017523189b2.json', '/jp2015052138b2.json', '/jp2014049916b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2015",
#         "invention_title": "식물 벌채 현장에서의 바이오매스 발전 시스템",
#         "ipc_section": "F",
#         "abstract": "(과제) 바이오매스를 연소해 그 열을 보일러로 회수해 증기 터빈으로 발전하는 소규모 시스템을 제공한다. (해결수단) 바이오매스 연료용 식물을 보관하는 용기 또는 창고, 그래서 보관된 연료 자원을 투입해 열분해에 의해 다른 연료 보급을 필요로 하는 무사히 이 연료 자원을 건조시킴에 필요한 열을 발생하는 장치, 연료 자원을 건조시켜 열분해에 의해 연소 가스를 발생하는 장치, 이 가스를 연소시켜 고온의 물을 만들고 수증기를 발생시키는 장치, 이 수증기를 발전기로 직결한 증기 터빈으로 증기를 공급하는 장치, 이 증기에 의해 구동되는 터빈, 그에 직결된 발전기, 터빈 구동에 사용된 증기를 복수 하는 복수기, 이것 등의 기기를 종합적으로 관리하는 제어장치로부터 구성되어 폐기물 투입 저장 처리조의 형상을 열분해 및 그에 이어서 일어나는 가스화가 용이하게 행해지는 것처럼 상부가 넓게 하부가 좁은 형상으로 한 일을 특징으로 한 소형 발전 시스템. (선택도) 도 1.",
#         "ipc_subclass": "F23B",
#         "applicant_name": "산지 마사키",
#         "ipc_main": "F23B-050/12",
#         "ipc_all": "F23B-050/12|A01G-023/00|F01K-027/02|F22B-001/18|F23B-090/06|F23G-005/027",
#         "ipc_class": "F23",
#         "claims": "바이오매스 연료용 식물을 현장에서 벌채해 연료 자원으로서 보관하는 용기 또는 창고, 그래서 보관된 연료 자원을 투입해 열분해에 의해 다른 연료 보급을 필요로 하는 무사히 이 연료 자원을 건조시킴에 필요한 열을 발생하는 장치, 이 발생한 열에 의해 연료 자원을 건조시켜 열분해에 의해 연소 가스를 발생하는 장치, 이 가스를 연소시켜 고온의 물을 만들고 수증기를 발생시키는 장치, 이 수증기를 발전기로 직결한 증기 터빈으로 증기를 공급하는 장치, 이 증기에 의해 구동되는 터빈, 그에 직결된 발전기, 터빈 구동에 사용된 증기를 복수 하는 복수기, 이것 등의 기기를 종합적으로 관리하는 제어장치로부터 구성되어 현장에 대량으로 있는 식물의 연료 자원을 다른 에너지를 이용하는 무사히, 현장에서 직접 벌채되는 연료 자원을 연료 자원의 형상으로 매치해, 폐기물 투입 저장 처리조의 형상을 열분해 및 그에 이어서 일어나는 가스화가 용이하게 행해지는 것처럼 상부가 넓게 하부가 좁은 형상으로서 현장에서의 가공을 최소로 해 폐기물의 투입 할 수 있는 것처럼 한 일을 특징으로 하고, 제어는 빅 데이터의 활용에 의하여 모든 관련하는 기기를 효율적으로 운전하고, 현장에 있는 연료 자원인 식물을 전기 에너지로 변환하는 일을 특징으로 한 소형 발전 시스템.",
#         "application_date": "20150529",
#         "documentId": "jp2015120623a",
#         "application_number": "2015-120623"
#     }
# }

# %%
# RAW 데이터셋을 하나의 리스트로 모으기

raw_dataset_list = []

for zip_file in os.listdir(raw_dataset_folder):
    
    zip_file_path = os.path.join(raw_dataset_folder, zip_file)
    # print(zip_file_path)
    middle_code = zip_file_path.split("_")[7]
    print("국가중점기술분류 중분류코드:", middle_code)

    with zipfile.ZipFile(zip_file_path, "r") as raw_zip_file:
        json_files = [
            file_name
            for file_name in raw_zip_file.namelist()
            if file_name.endswith(".json")
        ]
        print("현재 ZIP 폴더 총 파일 개수:", len(raw_zip_file.namelist()))
        print("현재 ZIP 폴더 JSON 파일 개수:", len(json_files))
        print(json_files[:5])
        print("예시 JSON 파일 내용:")

        for json_file in json_files:
            with raw_zip_file.open(json_file, "r") as example:
                json_example = example.read().decode("utf-8")
        
            data = json.loads(json_example)
            # raw 데이터셋 리스트에 추가하기
            raw_dataset_list.append(data)

        print(json.dumps(data, indent=4, ensure_ascii=False))
        print()

print("총 데이터셋 개수:", len(raw_dataset_list))
print(raw_dataset_list[0])
# Out:
# 국가중점기술분류 중분류코드: CCC
# 현재 ZIP 폴더 총 파일 개수: 3641
# 현재 ZIP 폴더 JSON 파일 개수: 3641
# ['/jp2002578212a.json', '/jp2002313500a.json', '/jp2019028834b1.json', '/jp2001508777a.json', '/jp2008336140a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2023",
#         "invention_title": "인공지능에 기반한 최적 광고 추천 시스템",
#         "ipc_section": "G",
#         "register_date": "20230721",
#         "abstract": "일실시예에 따르면, 인공지능에 기반한 최적 광고 추천 시스템에 있어서, 인공지능에 기반한 최적 광고를 추천하는 서버를 포함하는 시스템이 제공된다.",
#         "ipc_subclass": "G06Q",
#         "applicant_name": "그린브릭스컴퍼니 주식회사",
#         "ipc_main": "G06Q-030/02",
#         "register_year": "2023",
#         "ipc_all": "G06Q-030/02|G06N-003/0442|G06N-003/045|G06N-003/0464|G06N-003/0475|G06N-003/08|G06N-003/094",
#         "ipc_class": "G06",
#         "claims": "인공지능에 기반한 최적 광고 추천 시스템에 있어서,인공지능에 기반한 광고를 추천하는 서버를 포함하고,상기 서버는,데이터 수집부;데이터 분석부; 및광고 추천부를 포함하고,상기 데이터 수집부는,소정의 검색 포털 사이트 서버를 통해, 상기 검색 포털 사이트의 소정의 광고 위치에 디스플레이된 광고 데이터인 제1 데이터를 주기적으로 수집하되, 상기 제1 데이터는 광고 콘텐츠, 디스플레이 기간, 노출수, CTR(Click Through Rate: 클릭률), CVR(ConVersion Rate: 전환율), CPA(Cost Per Action: 전환당 비용), 및 랜딩 페이지 데이터를 포함하고,상기 데이터 분석부는,상기 제1 데이터의 디스플레이 기간과 노출수 및 CPA(전환당 비용)를 입력 데이터로, 시간대별, 요일별, 월별 예상 노출수 및 시간대별 예상 CPA를 예측하도록 제1 인공지능 모델을 학습시키되, 상기 제1 인공지능 모델은 LSTM(Long Short-Term Memory) 모델 또는 Prophet 모델이고,상기 제1 인공지능 모델이 예측한, 시간대별, 요일별, 월별 예상 노출수 및 상기 시간대별 예상 CPA를 Tableau, Microsoft Power BI, Google Data Studio 중 어느 하나의 도구를 이용하여 시각화하고,CTR(클릭률)이 1% 이상인 제1 데이터의 광고 콘텐츠를 입력 데이터로, 새로운 광고 콘텐츠를 생성하도록 제2 인공지능 모델을 학습시키되, 상기 제2 인공지능 모델은 GAN(Generative Adversarial Network) 모델이고,CVR(전환율)이 5% 이상인 제1 데이터의 랜딩 페이지 데이터를 입력 데이터로, 새로운 랜딩 페이지를 생성하도록 제3 인공지능 모델을 학습시키되, 상기 제3 인공지능 모델은 GAN(Generative Adversarial Network) 모델이고,상기 제1 인공지능 모델 내지 제3 인공지능 모델은,주기적으로 수집되는 제1 데이터에 따라 주기적으로 추가 학습되고,상기 데이터 수집부는,광고주 단말을 통해 입력된, 광고 상품의 랜딩 페이지로 사용될 웹 페이지 주소를 기반으로, 상기 웹 페이지 데이터인 제2 데이터를 수집하고,상기 데이터 분석부는,이미지와 텍스트를 분석하도록 기학습된 제4 인공지능 모델에, 상기 제2 데이터를 입력하여 상기 광고 상품의 정보를 획득하되, 상기 제4 인공지능 모델은, Faster R-CNN 또는 YOLO 모델과, OCR(Optical Character Recognition) 모델, 및 BERT 모델을 포함하는 다중 모달 분석(Multi-modal Analysis) 기술을 이용하고,상기 제2 인공지능 모델에, 상기 광고 상품의 정보를 입력하여 상기 광고 상품의 정보를 기반으로 하는 새로운 광고 콘텐츠를 생성하고,상기 제3 인공지능 모델에, 상기 광고 상품의 정보를 입력하여 상기 광고 상품의 정보를 기반으로 하는 새로운 랜딩 페이지를 생성하고,상기 광고 추천부는,상기 광고주 단말에, 상기 데이터 분석부가 시각화한 시간대별, 요일별, 월별 예상 노출수 및 상기 시간대별 예상 CPA와, 상기 제2 인공지능 모델에서 생성한 상기 광고 상품의 정보를 기반으로 하는 새로운 광고 콘텐츠와, 상기 제3 인공지능 모델에서 생성한 상기 광고 상품의 정보를 기반으로 하는 새로운 랜딩 페이지를 전송하는, 시스템.",
#         "application_date": "20230329",
#         "register_number": "2559950",
#         "documentId": "kr20230041575b1",
#         "application_number": "2023-0041575"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDB
# 현재 ZIP 폴더 총 파일 개수: 3455
# 현재 ZIP 폴더 JSON 파일 개수: 3455
# ['/jp2008527187b2.json', '/jp2012526898b2.json', '/jp2015560404a.json', '/jp2005171364b2.json', '/jp2005013318b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2021",
#         "invention_title": "자동차 시스템들에 대한 동적 재구성가능 인-필드 셀프-테스트능력",
#         "ipc_section": "G",
#         "open_number": "2023-0118697",
#         "abstract": "여러 실시형태들은 안전성 요건의 이들의 준수를 검증하기 위하여 테스트를 요구하는 서브시스템들을 식별하도록 구성된 컴포넌트들 (예를 들어, 차량의 어드밴스드 운전자 보조 시스템 내의 프로세서) 을 포함한다. 컴포넌트들은 준수의 검증이, 서브시스템들이 PON에서, POFF에서, 런타임 동안 또는 이들의 조합에서 테스트되는 것을 요구하는지 여부를 결정하고, 식별된 서브시스템들을 테스트하기 위해 달성가능한 병렬성을 동적으로 결정하고, 각각의 식별된 서브시스템에 대해 빌트 인 셀프 테스트들(BIST들)을 수행하거나 실행하기 위한 커버리지 레벨 요건들을 동적으로 결정하고, 결정된 병렬성의 레벨에서 그리고 결정된 커버리지 레벨에서 서브시스템들에 대해 BIST들을 수행하거나 실행할 수 있다.",
#         "ipc_subclass": "G06F",
#         "applicant_name": "퀄컴 인코포레이티드",
#         "ipc_main": "G06F-011/27",
#         "ipc_all": "G06F-011/27|E03C-001/046|G06F-011/22",
#         "ipc_class": "G06",
#         "claims": "차량에 포함된 전자 컴포넌트들을 인-필드 테스트하는 (in-field testing) 방법으로서, 프라이머리 부트 프로세서의 전용 로컬 슈퍼바이저 안전 관리기 컴포넌트에서, 상기 차량의 안전 필수 자동차 애플리케이션 (safety critical automotive application) 과 연관된 서브시스템들의 리스트를 수신하는 단계; 상기 서브시스템들의 리스트에서 각각의 서브시스템에 대한 상기 전용 로컬 슈퍼바이저 안전 관리기 컴포넌트에 의해, 안전성 요건의 준수의 검증이, 상기 서브시스템이 PON (power-on) 시, POFF (power-off) 시, 또는 런타임 동안에 테스트되는 것을 요구하는지의 여부를 결정하는 단계; 상기 서브시스템들의 리스트에서 각각의 서브시스템에 대한 상기 전용 로컬 슈퍼바이저 안전 관리기 컴포넌트에 의해, 그 서브시스템에 대한 BIST (built in self test) 를 수행하기 위해 요구되는 커버리지 레벨을 동적으로 결정하는 단계; 및 결정된 상기 커버리지 레벨에서 상기 서브시스템들에 대해 BIST들을 수행하는 단계를 포함하는, 차량에 포함된 전자 컴포넌트들을 인-필드 테스트하는 방법. 컴퓨팅 디바이스로서, 차량의 안전 필수 자동차 애플리케이션과 연관된 서브시스템들의 리스트를 수신하고; 상기 서브시스템들의 리스트에서 각각의 서브시스템에 대해, 안전성 요건의 준수의 검증이, 상기 서브시스템이 PON (power-on) 시, POFF (power-off) 시, 또는 런타임 동안에 테스트되는 것을 요구하는지의 여부를 결정하고; 상기 서브시스템들의 리스트에서 각각의 서브시스템에 대해, 그 서브시스템에 대한 BIST (built in self test) 를 수행하기 위해 요구되는 커버리지 레벨을 동적으로 결정하고; 그리고 결정된 상기 커버리지 레벨에서 상기 서브시스템들에 대해 BIST들을 수행하도록프로세서-실행가능 소프트웨어 명령들로 구성된 프라이머리 부트 프로세서를 포함하는, 컴퓨팅 디바이스.차량에 사용하기 위한 컴퓨팅 디바이스로서, 프라이머리 부트 프로세서의 전용 로컬 슈퍼바이저 안전 관리기 컴포넌트에서, 상기 차량의 안전 필수 자동차 애플리케이션 (safety critical automotive application) 과 연관된 서브시스템들의 리스트를 수신하기 위한 수단; 상기 서브시스템들의 리스트에서 각각의 서브시스템에 대한 상기 전용 로컬 슈퍼바이저 안전 관리기 컴포넌트에 의해, 안전성 요건의 준수의 검증이, 상기 서브시스템이 PON (power-on) 시, POFF (power-off) 시, 또는 런타임 동안에 테스트되는 것을 요구하는지의 여부를 결정하기 위한 수단; 상기 서브시스템들의 리스트에서 각각의 서브시스템에 대한 상기 전용 로컬 슈퍼바이저 안전 관리기 컴포넌트에 의해, 그 서브시스템에 대한 BIST (built in self test) 를 수행하기 위해 요구되는 커버리지 레벨을 동적으로 결정하기 위한 수단; 및 결정된 상기 커버리지 레벨에서 상기 서브시스템들에 대해 BIST들을 수행하기 위한 수단을 포함하는, 차량에 사용하기 위한 컴퓨팅 디바이스. 프로세서-실행가능 소프트웨어 명령들이 저장된 비-일시적인 컴퓨터 판독가능 저장 매체로서,상기 프로세서-실행가능 소프트웨어 명령들은 프로세서로 하여금 차량에 포함된 인-필드 테스트 전자 컴포넌트들을 위한 동작들을 수행하게 하도록 구성되고, 상기 동작들은: 상기 차량의 안전 필수 자동차 애플리케이션과 연관된 서브시스템들의 리스트를 수신하는 것; 상기 서브시스템들의 리스트에서 각각의 서브시스템에 대해, 안전성 요건의 준수의 검증이, 상기 서브시스템이 PON (power-on) 시, POFF (power-off) 시, 또는 런타임 동안에 테스트되는 것을 요구하는지의 여부를 결정하는 것; 상기 서브시스템들의 리스트에서 각각의 서브시스템에 대해, 그 서브시스템에 대한 BIST (built in self test) 를 수행하기 위해 요구되는 커버리지 레벨을 동적으로 결정하는 것; 및 결정된 상기 커버리지 레벨에서 상기 서브시스템들에 대해 BIST들을 수행하는 것을 포함하는, 비일시적 컴퓨터 판독가능 저장 매체.",
#         "application_date": "20211206",
#         "documentId": "kr20237025327a",
#         "application_number": "2023-7025327"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDB
# 현재 ZIP 폴더 총 파일 개수: 432
# 현재 ZIP 폴더 JSON 파일 개수: 432
# ['/jp2016157795a.json', '/jp2016511830b2.json', '/jp2008527094a.json', '/jp2016527099b2.json', '/jp2020028056a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2021",
#         "invention_title": "산업 시스템을 시뮬레이트하기 위한 컴퓨팅 플랫폼 및 시뮬레이션을 관리하는 방법",
#         "ipc_section": "G",
#         "open_number": "2023-0084483",
#         "abstract": "산업 시스템을 시뮬레이트하기 위한 컴퓨팅 플랫폼 및 시뮬레이션을 관리하는 방법이 개시된다. 방법은 산업 시스템의 시뮬레이션 모델의 적어도 하나의 인스턴스를 생성하는 단계를 포함하고, 방법은, 이종 프로세서들(242, 262) 중 제1 프로세서(242)와 연관된 동적 메모리 영역(252)에 대해 연속 메모리 할당기를 사용하여 인스턴스(342)를 생성하는 단계; 제2 프로세서(262)가 인스턴스의 카피(362)의 어드레스와 연관된 메모리 포인터에 기초하여 동적 메모리 영역(252) 내의 인스턴스(342)를 사용할 수 있게 하는 단계; 및 인스턴스 카피(362)에 액세스함으로써 제2 프로세서(262)에 의해 산업 시스템을 시뮬레이트하는 단계를 포함하는 것을 특징으로 한다.",
#         "ipc_subclass": "G06F",
#         "applicant_name": "지멘스 인더스트리 소프트웨어 엔브이",
#         "ipc_main": "G06F-030/20",
#         "ipc_all": "G06F-030/20|G06T-001/60",
#         "ipc_class": "G06",
#         "claims": "이종 프로세서들(242, 262)을 사용하는 산업 시스템에 대한 시뮬레이션을 관리하는 방법으로서,상기 산업 시스템의 시뮬레이션 모델의 적어도 하나의 인스턴스를 생성하는 단계를 포함하고,상기 방법은,상기 이종 프로세서들(242, 262)로부터의 제1 프로세서(242)와 연관된 제1 메모리(250) 내의 동적 메모리 영역(252)을 할당하기 위해 연속 메모리 할당기를 생성하는 단계 ― 상기 시뮬레이션 모델은 상기 제1 메모리(250) 내의 상기 동적 메모리 영역(252)에 저장됨 ―;상기 이종 프로세서들(242, 262) 중 제1 프로세서(242)와 연관된 상기 동적 메모리 영역(252)에 대해 상기 연속 메모리 할당기를 사용하여 상기 인스턴스(342)를 생성하는 단계 ― 상기 인스턴스를 생성하는 단계는, 상기 인스턴스에 의한 요청들에 응답하여 상기 연속 메모리 할당기에 의해 동적 할당들(346, 348)을 제공하는 단계를 포함하고, 상기 동적 할당들(346, 348)은 상기 동적 메모리 영역(252)에서 제공됨 ―;상기 이종 프로세서들(242, 262) 중 제2 프로세서(262)가 상기 인스턴스(342)의 카피(362)의 어드레스와 연관된 메모리 포인터에 기초하여 상기 동적 메모리 영역(252) 내의 상기 인스턴스(342)를 사용할 수 있게 하는 단계; 및상기 인스턴스 카피(362)에 액세스함으로써 상기 제2 프로세서(262)에 의해 상기 산업 시스템을 시뮬레이트하는 단계를 포함하고, 상기 동적 할당들(346, 348)은 특수 메모리 포인터 인스턴스(344)에 의해 상대적으로 참조되고, 상기 특수 메모리 포인터 인스턴스(344, 364)는 상기 동적 할당들(346, 348)과 그의 상대적 거리를 결정하도록 구성되고, 상기 메모리 포인터는 상기 특수 메모리 포인터 인스턴스(344, 364)를 사용하여 생성되는 것을 특징으로 하는, 방법.산업 시스템을 시뮬레이트하기 위한 컴퓨팅 플랫폼으로서,1. 2개 이상의 이종 프로세서(242, 262) ― 상기 2개 이상의 이종 프로세서(242, 262)는 제1 프로세서(242) 및 제2 프로세서(262)를 포함함 ―;2. 상기 제1 프로세서(242)와 연관된 제1 메모리(250) 및 상기 제2 프로세서(262)와 연관된 제2 메모리(270); 및3. 메모리 할당 모듈을 포함하고,상기 메모리 할당 모듈은,a. 상기 제1 메모리(250) 내의 동적 메모리 영역(252)을 할당하기 위해 연속 메모리 할당기를 생성하고 ― 시뮬레이션 모델이 상기 제1 메모리(250) 내의 상기 동적 메모리 영역(252)에 저장되고, 상기 연속 메모리 할당기는 상기 시뮬레이션 모델의 인스턴스(342)에 의한 요청들에 응답하여 동적 할당들(346, 348)을 제공하기 위한 것이고, 상기 동적 할당들(346, 348)은 상기 동적 메모리 영역(252)에서 제공됨 ―,b. 상기 이종 프로세서들(242, 262) 중 제2 프로세서(262)가 상기 인스턴스(342)의 카피(362)의 어드레스와 연관된 메모리 포인터에 기초하여 상기 동적 메모리 영역(252) 내의 상기 인스턴스(342)를 사용할 수 있게 하도록구성되고,상기 동적 할당들(346, 348)은 특수 메모리 포인터 인스턴스(344)에 의해 상대적으로 참조되고, 상기 특수 메모리 포인터 인스턴스(344, 364)는 상기 동적 할당들(346, 348)과 그의 상대적 거리를 결정하도록 구성되고, 상기 메모리 포인터는 상기 특수 메모리 포인터 인스턴스(344, 364)를 사용하여 생성되는, 컴퓨팅 플랫폼.컴퓨터 프로그램 제품으로서,머신 판독가능 명령어들을 저장하고,상기 머신 판독가능 명령어들은, 제10항 또는 제11항에 따른 컴퓨팅 플랫폼에 의해 실행될 때, 상기 컴퓨팅 플랫폼으로 하여금 제1항 내지 제9항 중 어느 한 항에 따른 방법 단계들을 수행하게 하는, 컴퓨터 프로그램 제품.",
#         "application_date": "20210825",
#         "documentId": "kr20237010407a",
#         "application_number": "2023-7010407"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDC
# 현재 ZIP 폴더 총 파일 개수: 3588
# 현재 ZIP 폴더 JSON 파일 개수: 3588
# ['/jp2015043323b2.json', '/jp2016205574b2.json', '/jp2014101507a.json', '/jp2014236256b2.json', '/jp2014110103b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2022",
#         "invention_title": "소프트웨어 정의 광역 네트워크(SD-WAN)를 위한 수평적 스케일링",
#         "ipc_section": "H",
#         "open_number": "2023-0054716",
#         "abstract": "네트워크들을 관리하기 위한 시스템들, 장치들, 방법들 및 컴퓨터 판독가능 매체들이 개시된다. 적어도 하나의 예에 따르면, 상이한 지역들에 걸쳐 네트워크 컨트롤러에 접속하기 위한 방법이 제공된다. 방법은 네트워크 컨트롤러로부터의 네트워크 오케스트레이터와의 제2 접속의 확립 동안, 네트워크 오케스트레이터와의 제1 접속을 식별하는 단계; 제어 평면에서 제2 접속과 제1 접속을 링크하는 시블링 세션을 확립하는 단계; 시블링 세션을 식별하는 시블링 데이터 메시지를 송신되는 제어 메시지들에 삽입하는 단계; 제2 접속을 통해 네트워크 오케스트레이터로부터 메시지를 수신하는 단계 - 메시지는 제2 접속에 연관된 네트워크 컨트롤러의 어드레스를 포함함 - ; 및 제1 접속을 통해 네트워크 컨트롤러의 제2 어드레스를 네트워크 오케스트레이터에 전송하는 단계를 포함한다.",
#         "ipc_subclass": "H04L",
#         "applicant_name": "시스코 테크놀러지, 인크.",
#         "ipc_main": "H04L-041/342",
#         "ipc_all": "H04L-041/342|H04L-101/686|H04L-045/76|H04L-061/2514|H04L-067/141|H04L-009/40",
#         "ipc_class": "H04",
#         "claims": "방법으로서,네트워크 컨트롤러로부터의 네트워크 오케스트레이터(network orchestrator)와의 제2 접속의 확립 동안, 상기 네트워크 오케스트레이터와의 제1 접속을 식별하는 단계;제어 평면에서 상기 제2 접속과 상기 제1 접속을 링크하는 시블링 세션(sibling session)을 확립하는 단계;상기 시블링 세션을 식별하는 시블링 데이터 메시지를 송신되는 제어 메시지들에 삽입하는 단계;상기 제2 접속을 통해 상기 네트워크 오케스트레이터로부터 메시지를 수신하는 단계 - 이 메시지는 상기 제2 접속에 연관된 상기 네트워크 컨트롤러의 어드레스를 포함함 - ; 및상기 제1 접속을 통해 상기 네트워크 컨트롤러의 상기 제2 어드레스를 상기 네트워크 오케스트레이터에 전송하는 단계 - 상기 네트워크 오케스트레이터는 상기 네트워크 컨트롤러의 상기 제2 어드레스를 수신하고, 상기 제1 접속 및 상기 제2 접속을 단일 논리 접속으로서 연관시킴 -를 포함하고, 상기 네트워크 오케스트레이터는 네트워크 에지 디바이스들의 셋업 동안 상기 제1 어드레스 및 상기 제2 어드레스를 전송하도록 구성되는, 방법.네트워크 오케스트레이터의 방법으로서,제1 접속이 제2 접속에 관련됨을 나타내는 시블링 데이터 메시지를 포함하는 메시지를 수신하는 단계 - 이 메시지는 네트워크 컨트롤러로 상기 제1 접속 및 상기 제2 접속이 확립될 때 수신됨 - ;메시지를 상기 제2 접속을 통해 상기 네트워크 컨트롤러에 전송하는 단계 - 이 메시지는 상기 네트워크 컨트롤러의 제2 어드레스를 포함함 - ;상기 네트워크 컨트롤러로부터 상기 제1 접속을 통해 상기 제2 접속에 연관된 상기 네트워크 컨트롤러의 어드레스를 수신하는 단계;상기 제1 접속과 상기 제2 접속을 연관시키는 단계; 및네트워크 에지 디바이스에 접속하기 위한 요청을 수신한 것에 응답하여, 단일 접속을 통해 상기 네트워크 에지 디바이스에 메시지를 전송하는 단계 - 이 메시지는 상기 제1 접속에 연관된 상기 네트워크 컨트롤러의 제1 어드레스, 및 상기 제2 어드레스를 식별함 -를 포함하는, 방법.네트워크 컨트롤러로서,송수신기; 및명령어들을 실행하도록 구성되는 프로세서를 포함하고, 상기 프로세서는 상기 프로세서로 하여금:상기 네트워크 컨트롤러로부터의 네트워크 오케스트레이터와의 제2 접속의 확립 동안, 상기 네트워크 오케스트레이터와의 제1 접속을 식별하게 하고;제어 평면에서 상기 제2 접속과 상기 제1 접속을 링크하는 시블링 세션을 확립하게 하고;상기 시블링 세션을 식별하는 시블링 데이터 메시지를 제어 메시지들에 삽입하게 하고;상기 제2 접속을 통해 상기 네트워크 오케스트레이터로부터 메시지를 수신하게 하고 - 이 메시지는 상기 제2 접속에 연관된 상기 네트워크 컨트롤러의 어드레스를 포함함 - ; 및상기 제1 접속을 통해 상기 네트워크 컨트롤러의 상기 제2 어드레스를 상기 네트워크 오케스트레이터에 전송하게 하도록 - 상기 네트워크 오케스트레이터는 상기 네트워크 컨트롤러의 상기 제2 어드레스를 수신하고, 상기 제1 접속 및 상기 제2 접속을 단일 논리 접속으로서 연관시킴 -구성되고, 상기 네트워크 오케스트레이터는 네트워크 에지 디바이스들의 셋업 동안 상기 제1 어드레스 및 상기 제2 어드레스를 전송하도록 구성되는, 네트워크 컨트롤러.네트워크 컨트롤러로서,상기 네트워크 컨트롤러로부터의 네트워크 오케스트레이터와의 제2 접속의 확립 동안, 상기 네트워크 오케스트레이터와의 제1 접속을 식별하기 위한 수단;제어 평면에서 상기 제2 접속과 상기 제1 접속을 링크하는 시블링 세션을 확립하기 위한 수단;상기 시블링 세션을 식별하는 시블링 데이터 메시지를 제어 메시지들에 삽입하기 위한 수단;상기 제2 접속을 통해 상기 네트워크 오케스트레이터로부터 메시지를 수신하기 위한 수단 - 이 메시지는 상기 제2 접속에 연관된 상기 네트워크 컨트롤러의 어드레스를 포함함 - ; 및상기 제1 접속을 통해 상기 네트워크 컨트롤러의 상기 제2 어드레스를 상기 네트워크 오케스트레이터에 전송하기 위한 수단 - 상기 네트워크 오케스트레이터는 상기 네트워크 컨트롤러의 상기 제2 어드레스를 수신하고, 상기 제1 접속 및 상기 제2 접속을 단일 논리 접속으로서 연관시킴 -을 포함하고, 상기 네트워크 오케스트레이터는 네트워크 에지 디바이스들의 셋업 동안 상기 제1 어드레스 및 상기 제2 어드레스를 전송하도록 구성되는, 네트워크 컨트롤러.네트워크 오케스트레이터로서,제1 접속이 제2 접속에 관련됨을 나타내는 시블링 데이터 메시지를 포함하는 메시지를 수신하기 위한 수단 - 이 메시지는 네트워크 컨트롤러로 상기 제1 접속 및 상기 제2 접속이 확립될 때 수신됨 - ;메시지를 상기 제2 접속을 통해 상기 네트워크 컨트롤러에 전송하기 위한 수단 - 이 메시지는 상기 네트워크 컨트롤러의 제2 어드레스를 포함함 - ;상기 네트워크 컨트롤러로부터 상기 제1 접속을 통해 상기 제2 접속에 연관된 상기 네트워크 컨트롤러의 어드레스를 수신하기 위한 수단;상기 제1 접속과 상기 제2 접속을 연관시키기 위한 수단; 및네트워크 에지 디바이스에 접속하기 위한 요청을 수신한 것에 응답하여, 단일 접속을 통해 상기 네트워크 에지 디바이스에 메시지를 전송하기 위한 수단 - 이 메시지는 상기 제1 접속에 연관된 상기 네트워크 컨트롤러의 제1 어드레스, 및 상기 제2 어드레스를 식별함 -을 포함하는, 네트워크 오케스트레이터.컴퓨터 프로그램, 컴퓨터 프로그램 제품 또는 컴퓨터 판독가능 매체로서,컴퓨터에 의해 실행될 때, 상기 컴퓨터로 하여금 제1항 내지 제12항 중 어느 한 항의 방법의 단계들을 수행하게 하는 명령어들을 포함하는 컴퓨터 프로그램, 컴퓨터 프로그램 제품 또는 컴퓨터 판독가능 매체.",
#         "application_date": "20220407",
#         "documentId": "kr20237010020a",
#         "application_number": "2023-7010020"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDC
# 현재 ZIP 폴더 총 파일 개수: 451
# 현재 ZIP 폴더 JSON 파일 개수: 451
# ['/jp2016573612b2.json', '/kr20000066328a.json', '/jp2019124440a.json', '/jp2017158158b2.json', '/jp2022097494a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2017",
#         "invention_title": "미디어 오버레이들에서의 커스터마이즈된 아바타들의 생성 및 디스플레이",
#         "ipc_section": "G",
#         "open_number": "2023-0070317",
#         "abstract": "다른 것들 중에서, 본 개시내용의 실시예들은 미디어 오버레이들을 생성하고 상이한 사용자들의 아바타들과 함께 미디어 오버레이들을 디스플레이함으로써 전자 메시징 및 이미징 소프트웨어 및 시스템들의 기능성을 개선한다. 예를 들어, 미디어 오버레이들은 시스템에 의해 생성되고 이미지 캡처링 디바이스(예를 들어, 디지털 카메라)에 의해 생성된 미디어 콘텐츠(예를 들어, 이미지들 및/또는 비디오)와 함께 디스플레이될 수 있다.",
#         "ipc_subclass": "G06Q",
#         "applicant_name": "스냅 인코포레이티드",
#         "ipc_main": "G06Q-050/10",
#         "ipc_all": "G06Q-050/10|G06F-003/01|G06Q-050/30|G06T-013/40|G06T-019/00|G06T-019/20|H04L-051/046|H04L-051/07",
#         "ipc_class": "G06",
#         "claims": "시스템으로서,적어도 하나의 프로세서;상기 프로세서에 의해 실행될 때, 상기 시스템으로 하여금 동작들을 수행하게 하는 명령어들을 저장하는 메모리 스토리지 디바이스를 포함하고, 상기 동작들은,제1 최종 사용자의 클라이언트 디바이스로부터, 제2 최종 사용자의 상태를 보기 위한 요청을 수신하는 동작;상기 요청에 응답하여:상기 제2 최종 사용자의 현재 위치를 나타내는 제1 위치 데이터를 획득하는 동작;상기 제1 최종 사용자의 상기 클라이언트 디바이스에서 처리될 때, 상기 제1 최종 사용자의 상기 클라이언트 디바이스로 하여금 미디어 오버레이를 갖는 미디어 콘텐츠 아이템을 포함하는 사용자 인터페이스를 제시하게 하는 명령어들을 생성하는 동작 - 상기 미디어 오버레이는 i) 상기 제2 최종 사용자를 나타내는 아바타를 포함하고, ii) 상기 제1 위치 데이터에 기초하여 선택됨 -; 및상기 제1 최종 사용자의 상기 클라이언트 디바이스에 상기 명령어들을 통신하여, 상기 사용자 인터페이스가 상기 클라이언트 디바이스의 디스플레이를 통해 제시되게 하는 동작을 포함하는, 시스템.컴퓨터 구현 방법으로서, 제1 최종 사용자의 클라이언트 디바이스로부터, 제2 최종 사용자의 상태를 보기 위한 요청을 수신하는 단계;상기 요청에 응답하여:상기 제2 최종 사용자의 현재 위치를 나타내는 제1 위치 데이터를 획득하는 단계;상기 제1 최종 사용자의 상기 클라이언트 디바이스에서 처리될 때, 상기 제1 최종 사용자의 상기 클라이언트 디바이스로 하여금 미디어 오버레이를 갖는 미디어 콘텐츠 아이템을 포함하는 사용자 인터페이스를 제시하게 하는 명령어들을 생성하는 단계 - 상기 미디어 오버레이는 i) 상기 제2 최종 사용자를 나타내는 아바타를 포함하고, ii) 상기 제1 위치 데이터에 기초하여 선택됨 -; 및상기 제1 최종 사용자의 상기 클라이언트 디바이스에 상기 명령어들을 통신하여, 상기 사용자 인터페이스가 상기 클라이언트 디바이스의 디스플레이를 통해 제시되게 하는 단계를 포함하는, 컴퓨터 구현 방법.명령어들을 저장하는 비일시적 컴퓨터 판독가능 매체로서, 상기 명령어들은, 서버 컴퓨터에 의해 실행될 때, 상기 서버 컴퓨터로 하여금 동작들을 수행하도록 하고, 상기 동작들은:제1 최종 사용자의 클라이언트 디바이스로부터, 제2 최종 사용자의 상태를 보기 위한 요청을 수신하는 동작;상기 요청에 응답하여:상기 제2 최종 사용자의 현재 위치를 나타내는 제1 위치 데이터를 획득하는 동작;상기 제1 최종 사용자의 상기 클라이언트 디바이스에서 처리될 때, 상기 제1 최종 사용자의 상기 클라이언트 디바이스로 하여금 미디어 오버레이를 갖는 미디어 콘텐츠 아이템을 포함하는 사용자 인터페이스를 제시하게 하는 명령어들을 생성하는 동작 - 상기 미디어 오버레이는 i) 상기 제2 최종 사용자를 나타내는 아바타를 포함하고, ii) 상기 제1 위치 데이터에 기초하여 선택됨 -; 및상기 제1 최종 사용자의 상기 클라이언트 디바이스에 상기 명령어들을 통신하여, 상기 사용자 인터페이스가 상기 클라이언트 디바이스의 디스플레이를 통해 제시되게 하는 동작을 포함하는, 비일시적 컴퓨터 판독가능 매체.",
#         "application_date": "20171023",
#         "documentId": "kr20237015209a",
#         "application_number": "2023-7015209"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCA
# 현재 ZIP 폴더 총 파일 개수: 436
# 현재 ZIP 폴더 JSON 파일 개수: 436
# ['/jp2016233295a.json', '/jp2016531545a.json', '/jp2016519729b2.json', '/jp2014145916a.json', '/jp2014238759b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2023",
#         "invention_title": "맨홀 역류시 유실 방지용 맨홀 뚜껑 및 그를 이용한 맨홀 운영 관리 시스템",
#         "ipc_section": "E",
#         "register_date": "20230720",
#         "abstract": "본 발명은 맨홀 역류시 유실 방지용 맨홀 뚜껑 및 그를 이용한 맨홀 운영 관리 시스템에 관한 것으로, 보다 구체적으로는, 돌기와 홈부를 이용해서 맨홀 뚜껑을 커버하여 상부에서는 보이지 않는 구조로 체결됨으로써, 맨홀 내부에서 역류가 발생하더라도 맨홀 뚜껑이 상부로 열리지 않아 유실될 염려가 없고, 홍수시 행인이나 작업자 등의 인명사고 발생도 막을 수 있을 뿐만 아니라, 맨홀 뚜껑에 대한 이력 관리를 체계적으로 관리하도록 하기 위한 맨홀 역류시 유실 방지용 맨홀 뚜껑 및 그를 이용한 맨홀 운영 관리 시스템에 관한 것이다.",
#         "ipc_subclass": "E02D",
#         "applicant_name": "주식회사 동양이엔지",
#         "ipc_main": "E02D-029/14",
#         "register_year": "2023",
#         "ipc_all": "E02D-029/14|G06Q-050/10|G06Q-050/26|H04B-005/02",
#         "ipc_class": "E02",
#         "claims": "맨홀 뚜껑(120)과 프레임(100a)으로 이루어지며, 제어장치부(110)가 맨홀 뚜껑(120)의 상부 원형 커버(121)의 내부 및 외부의 적어도 하나 이상에 구비되며, 제어장치부(110)는 송수신부(111), MPU(112), 태양광모듈(114) 및 센서모듈(115)을 포함하는 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)가 복수로 이루어진 맨홀 역류시 유실 방지용 맨홀 뚜껑 그룹; 네트워크(200); 관리서버(300); 빅데이터 서버(400); 관리자단말(500); 및 관제센터(600); 를 포함하며, 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)의 송수신부(111)는 GPS 수신단을 구비함으로써, GPS 수신단에 의해 측정되는 GPS 위치 정보가 미리 설정된 임계치 이상으로 차이가 있는 것으로 MPU(112)에 의해 분석되는 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)의 유실이 발생하는 경우, MPU(112)가 네트워크(200)를 통해 관리서버(300)로 유실 이벤트 신호를 전송하도록 송수신부(111)를 제어하며,관리서버(300)는,유실된 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)에 관한 GPS 위치 정보를 빅데이터 서버(400) 상으로 실시간으로 저장하여 관리하며, 관제 센터(600)로 전달되도록 함으로써, 관제 센터(600)에서 관할 지역의 주민단말로 SMS를 통한 맨홀 뚜껑 유실로 인한 사고 위험에 관한 경고 방송이 발생할 수 있도록 하며, 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)의 센서모듈(115)에 의해 측정된 센싱정보를 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)의 송수신부(111)에 의해 네트워크(200)를 통해 수신한 뒤, 센싱정보 중 맨홀 내부 상태(가스, 수위 포함)에 관한 정보를 관제센터(600) 중 하나로 구성 가능한 시청을 포함한 맨홀 관리센터인 관제센터(600) 상에서 판단한 결과 이상 발생시 맨홀을 점검할 수 있도록 하며 작업자가 맨홀 점검시 관련 정보를 네트워크(200)를 통해 관리단말(500)로 제공함으로써, 작업자가 단말기를 통해 관련 정보를 수신하여 맨홀의 역류로 인한 유실시의 상태 정보로 참조하여 미리 대처하고 가스 중독을 포함한 사고를 방지할 수 있도록 하며, 센싱모듈(115)은 가스 감지센서, 수위 감지센서를 포함하며,태양광모듈(114)은 태양광 기능이 추가되는 경우 상부 원형 커버(121)의 상부면에 솔라셀어레이가 추가됨으로써, 자체 배터리 기능을 추가하여 외부 전력 공급이 없어도 제어장치부(110)를 구성하는 각 구성요소의 전원을 자체적으로 관리하며,가스 감지센서, 수위 감지센서에서 제공되는 센싱정보 중 적어도 하나 이상이 미리 설정된 임계치 이상이 변화되는 경우를 MPU(112)는 센서모듈(115)에 대한 모니터링을 통해 감지하여 관리자단말(500)에게 제공할 뿐만 아니라, MPU(112)는 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)의 유실방지 기능에 따라 맨홀 뚜껑 이탈시 맨홀 이탈에 따른 사고를 방지할 수 있는 기능도 제공하며,맨홀 역류시 유실 방지용 맨홀 뚜껑(100)은 원판 형태의 홀 뚜껑(120)에 상부에 형성된 태양광모듈(114)에는 LED 소자, 비콘송수신단을 더 포함하며,LED 소자는 R, G, B 소자가 하나의 패키지로 묶인 멀티 칼라 LED로 각 하나의 멀티 칼라 LED는 내부에 있는 R, G, B 소자의 색의 조합에 의해 색상 및 밝기의 조절되며, 색의 조합뿐만 아니라, PWM(Pulse Width Modulation) 방식을 활용함으로써 색상 및 밝기가 조절되며,MPU(112)는 태양광모듈(114)을 구성하는 솔라셀어레이에 의해 태양광 에너지가 전력 에너지로 변환되어 자체적으로 태양광모듈(114)의 캐퍼시터로 구성된 충전모듈저장되면, 태양광모듈(114)에 저장된 전원을 이용해 LED 소자에 대한 점등을 제어하고, 비콘송수신단을 통해 작업자가 소지하는 관리자단말(500)으로 비콘 신호를 통해 작업을 해야하는 맨홀 역류시 유실 방지용 맨홀 뚜껑(100) 역류시 유실 방지용 맨홀 뚜껑(100)의 실시간으로 이동하는 GPS 위치 정보를 전송하는 기능을 수행하며,비콘 신호를 수신한 관리자단말(500)은 관리자단말(500)에 형성된 비콘신호 디텍터를 통해 비콘 신호의 방향성 전환 탐지를 주기적으로 확인하고 비콘 신호의 방향성 전환 탐지가 되고, 탐지된 방향이 관리자단말(500)로 제공됨으로써, 작업자가 유실된 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)의 방향을 인지하고 대피하거나 유실된 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)을 수거하는데 도움을 주며,관리서버(300)는,각 관리자단말(500)로부터 네트워크(200)를 통한 액세스(access)를 통한 관제정보제공을 위한 SNS ID 및 비밀번호를 제공받을 뿐만 아니라, 관리자단말(500)의 단말식별번호(IMEI)를 수신하여 단말식별번호를 메타데이터로 SNS ID, 비밀번호를 회원 정보로 빅데이터 서버(400)에 저장함으로써, 관리자단말 그룹 전체에 대한 관제정보제공 회원 가입 절차를 완료하며, 하나의 관리자단말(500)에 의한 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)의 역류에 따른 유실이 발생하는 경우, 관리자단말(500)가 관리하는 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)의 GPS 위치 정보, GPS 위치 정보가 획득된 시간정보를 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)으로부터 네트워크(200)를 통해 수신한 뒤, 맨홀 역류시 유실 방지용 맨홀 뚜껑(100)에 대한 관리자로 지정된 관리자단말(500)의 단말식별번호를 메타데이터로 위치정보, 시간정보를 빅데이터 서버(400)에 추가로 저장하며,관리자단말(500)의 단말식별번호로 맨홀 역류시 유실된 유실 방지용 맨홀 뚜껑(100) 관련제보에 대한 유실 방지용 맨홀 뚜껑(100)의 실시간 GPS 위치 정보로부터 미리 설정된 구역 내에 속하는 위치 정보를 제공한 동일한 SNS 서비스 사용자단말의 SNS ID를 SNS 서버에 대한 요청을 통해 추출하여 추출된 사용자단말에 대한 푸쉬 메시지로 유실로 인한 위험 정보를 제공하고, 유실된 유실 방지용 맨홀 뚜껑(100)로부터 비콘 신호에 의한 사용자단말에 대한 인식과 미리 설정된 LED 점등 방식이 수행되어 사용자단말에 의해 촬영이 수행되는 경우, 촬영된 영상을 실시간으로 관리자단말(500)로 제공함으로써, SNS를 통한 관리자의 회수 조치가 이루어질 수 있도록 할 뿐만 아니라, 관리서버(300)가 관제센터(600)로 네트워크(200)를 통해 실시간 촬영정보를 제보하며,맨홀 뚜껑(120)의 상부 원형 커버(121) 하부에 돌기(122)를 구비하고 프레임(100a) 측면에 돌기(122)가 일측 방향으로 삽입될 수 있는 홈부(110a)를 구비한 구조를 가지며, 홈부(110a) 일측은 개방되고 타측은 막힌 구조를 가지며, 맨홀 뚜껑(120)을 하부로 내린 상태(닫은 상태)에서 옆으로 돌려 상부 원형 커버(121) 하부의 돌기(122)가 프레임(100a) 측면의 홈부(110a)로 삽입됨으로써 결속되게 하는 구조를 가지며, 돌기(122) 및 홈부(110a) 쌍은 3개 내지 4개이며, 상부 원형 커버(121)는 돌기(122) 및 홈부(110a)를 모두 커버하여 상부에서는 보이지 않게 체결됨으로써, 맨홀 내부에서 역류가 발생하더라도 맨홀 뚜껑이 상부로 열리지 않아 유실될 염려가 없고, 홍수시 인명사고 발생도 막는 구조를 가지는 것을 특징으로 하는 맨홀 역류시 유실 방지용 맨홀 뚜껑을 이용한 맨홀 운영 관리 시스템.",
#         "application_date": "20230403",
#         "register_number": "2559153",
#         "documentId": "kr20230043654b1",
#         "application_number": "2023-0043654"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCB
# 현재 ZIP 폴더 총 파일 개수: 3453
# 현재 ZIP 폴더 JSON 파일 개수: 3453
# ['/jp2003406801a.json', '/jp2005158299b2.json', '/jp2005045280a.json', '/jp2001533509a.json', '/jp2001043585a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2021",
#         "invention_title": "네트워크 내의 분산 데이터베이스를 위한 방법들 및 장치",
#         "ipc_section": "G",
#         "open_number": "2023-0107561",
#         "abstract": "일부 실시예들에서, 방법은 분산 데이터베이스에 대한 주소록을 정의하는 단계를 포함한다. 주소록은 네트워크를 통해 분산 데이터베이스를 구현하는 컴퓨팅 디바이스들의 세트로부터의 각각의 컴퓨팅 디바이스에 대한 식별자를 포함한다. 이 방법은 컴퓨팅 디바이스들의 세트로부터의 컴퓨팅 디바이스로부터, 주소록을 업데이트하기 위한 트랜잭션을 포함하는 이벤트를 수신하는 단계 및 주소록을 이용하는 분산 데이터베이스의 컨센서스 프로토콜에 기반하여, 이벤트에 대한 수신된 라운드를 계산하는 단계를 더 포함한다. 이 방법은 이벤트에 대한 수신된 라운드 또는 주소록에 대한 이전 업데이트 중 적어도 하나 후에 미리 결정된 수의 라운드로 업데이트된 주소록을 정의하기 위해 트랜잭션에 기반하여 주소록을 업데이트하는 단계를 더 포함한다.",
#         "ipc_subclass": "G06F",
#         "applicant_name": "헤데라 하쉬그라프, 엘엘씨",
#         "ipc_main": "G06F-016/27",
#         "ipc_all": "G06F-016/27|G06F-016/22|G06F-016/23|G06F-016/901",
#         "ipc_class": "G06",
#         "claims": "방법으로서,분산 데이터베이스에 대한 주소록을 정의하는 단계 - 상기 주소록은 네트워크를 통해 상기 분산 데이터베이스를 구현하는 복수의 컴퓨팅 디바이스로부터의 각각의 컴퓨팅 디바이스에 대한 식별자를 포함함 -;상기 복수의 컴퓨팅 디바이스로부터의 컴퓨팅 디바이스로부터, 상기 주소록을 업데이트하기 위한 트랜잭션을 포함하는 이벤트를 수신하는 단계;상기 주소록을 이용하는 상기 분산 데이터베이스의 컨센서스 프로토콜에 기반하여, 상기 이벤트에 대한 수신된 라운드(round)를 계산하는 단계; 및상기 이벤트에 대한 상기 수신된 라운드 또는 상기 주소록에 대한 이전 업데이트 중 적어도 하나 후에 미리 결정된 수의 라운드로 업데이트된 주소록을 정의하기 위해 상기 트랜잭션에 기반하여 상기 주소록을 업데이트하는 단계를 포함하는, 방법.장치로서,복수의 컴퓨팅 디바이스에 동작가능하게 결합된 네트워크를 통해 상기 복수의 컴퓨팅 디바이스에 의해 구현되는 분산 데이터베이스와 연관된 컴퓨팅 디바이스의 메모리; 및상기 메모리에 동작가능하게 결합된 프로세서를 포함하며, 상기 프로세서는,상기 분산 데이터베이스에 대한 주소록을 정의하고 - 상기 주소록은 상기 분산 데이터베이스를 구현하는 상기 복수의 컴퓨팅 디바이스로부터의 각각의 컴퓨팅 디바이스에 대한 식별자를 포함함 -;상기 복수의 컴퓨팅 디바이스로부터의 컴퓨팅 디바이스로부터, 상기 주소록을 업데이트하기 위한 트랜잭션을 포함하는 이벤트를 수신하고;복수의 이벤트로부터의 각각의 이벤트에 대한 속성을 계산하고 - 상기 이벤트는 상기 복수의 이벤트에 포함됨 -;상기 주소록을 이용하는 상기 분산 데이터베이스의 컨센서스 프로토콜에 기반하여, 상기 이벤트에 대한 수신된 라운드를 계산하고 - 상기 수신된 라운드는 상기 이벤트의 후손들인 이벤트들의 세트로부터의 임계 수의 이벤트들에 기반함 -;상기 이벤트에 대한 상기 수신된 라운드 또는 상기 주소록에 대한 이전 업데이트 중 적어도 하나 후에 미리 결정된 수의 라운드로 업데이트된 주소록을 정의하기 위해 상기 트랜잭션에 기반하여 상기 주소록을 업데이트하고;상기 업데이트된 주소록을 이용하여, 그 이벤트가 상기 이벤트들의 세트로부터의 후손 이벤트를 갖지 않을 때 상기 복수의 이벤트로부터의 각각의 이벤트에 대한 상기 속성을 재계산하도록 구성되는, 장치.프로세서에 의해 실행될 명령어들을 나타내는 코드를 저장한 비일시적 프로세서 판독가능한 매체로서, 상기 코드는 상기 프로세서로 하여금,네트워크를 통해, 분산 데이터베이스를 구현하는 복수의 컴퓨팅 디바이스에 그리고 상기 분산 데이터베이스를 구현하는 노드로서 연결하게 하고;상기 복수의 컴퓨팅 디바이스로부터의 컴퓨팅 디바이스로부터, 컨센서스 프로토콜의 완료된 라운드와 연관된 상기 분산 데이터베이스의 상태를 수신하게 하고 - 상기 상태는 이벤트들의 코어 세트로부터의 각각의 이벤트에 대한 라운드 식별자와 함께 상기 완료된 라운드와 연관된 상기 이벤트들의 코어 세트의 표시를 포함함 -;상기 복수의 컴퓨팅 디바이스로부터, 상기 상태와 연관된 복수의 이벤트를 수신하게 하고;상기 이벤트들의 코어 세트 및 상기 이벤트들의 코어 세트로부터의 각각의 이벤트에 대한 상기 라운드 식별자에 기반하여 상기 복수의 이벤트로부터의 각각의 이벤트에 대한 속성들의 세트를 계산하게 하고;상기 복수의 이벤트 및 상기 복수의 이벤트에 대한 상기 속성들의 세트에 기반하여 방향성 비순환 그래프(directed acyclic graph)(DAG)를 구성하게 하고;상기 DAG를 이용하여, 상기 컨센서스 프로토콜의 다음 라운드와 연관된 이벤트들의 순서를 계산하게 하는 코드를 포함하는, 비일시적 프로세서 판독가능한 매체.",
#         "application_date": "20211005",
#         "documentId": "kr20237015347a",
#         "application_number": "2023-7015347"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDA
# 현재 ZIP 폴더 총 파일 개수: 249
# 현재 ZIP 폴더 JSON 파일 개수: 249
# ['/jp2016020910b2.json', '/jp2020072671a.json', '/jp2012507606b2.json', '/jp2010038766a.json', '/jp2019548263b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2021",
#         "invention_title": "양자 회로를 위한 결함 허용 및 에러 정정 디코딩 방법 및 장치, 그리고 칩",
#         "ipc_section": "H",
#         "open_number": "2021-0144846",
#         "abstract": "본 출원은 양자 회로를 위한 결함 허용 및 에러 정정 디코딩 방법 및 장치, 및 칩을 개시하며, 인공 지능(AI) 및 양자 기술들의 분야에 관한 것이다. 방법은, 양자 회로의 실제 에러 신드롬 정보(actual error syndrome information)를 획득하는 단계 ―실제 에러 신드롬 정보는 양자 에러 정정(QEC: quantum error correction) 코드를 사용하여 양자 회로에 대해 잡음 에러 신드롬 측정을 수행함으로써 획득된 정보임―; 실제 에러 신드롬 정보에 대응하는 퍼펙트 에러 신드롬 정보 및 논리 에러 부류를 획득하기 위해 실제 에러 신드롬 정보를 디코딩하는 단계; 논리 에러 부류 및 퍼펙트 에러 신드롬 정보에 기반하여 양자 회로의 에러 결과 정보를 결정하는 단계 ―에러 결과 정보는 양자 회로에서 에러가 발생하는 데이터 큐비트(data qubit) 및 대응하는 에러 부류를 지시하는 데 사용됨―를 포함한다. 본 출원은, 결함 허용 및 에러 정정 디코딩을 분류 문제로 등가적으로 변환하고, 이에 따라 효율적인 뉴럴 네트워크 분류기를 사용하여 에러 신드롬 정보에 대해 결함 허용 및 에러 정정 디코딩이 수행될 수 있고, 이로써 결함 허용 및 에러 정정 디코딩 속도를 개선하고, 그리고 실시간 결함 허용 및 에러 정정 디코딩을 달성한다.",
#         "ipc_subclass": "H03M",
#         "applicant_name": "텐센트 테크놀로지(센젠) 컴퍼니 리미티드",
#         "ipc_main": "H03M-013/15",
#         "ipc_all": "H03M-013/15|G06N-010/00|H03M-013/00|H03M-013/01|B82Y-010/00",
#         "ipc_class": "H03",
#         "claims": "컴퓨터 디바이스에 적용가능한, 양자 회로를 위한 결함 허용 및 에러 정정(fault tolerant and error correction) 디코딩 방법으로서,양자 회로의 실제 에러 신드롬 정보(actual error syndrome information)를 획득하는 단계 ―상기 실제 에러 신드롬 정보는 양자 에러 정정(QEC: quantum error correction) 코드를 사용하여 상기 양자 회로에 대해 잡음성 에러 신드롬(noisy error syndrome) 측정을 수행함으로써 획득된 정보임―;상기 실제 에러 신드롬 정보에 대응하는 퍼펙트 에러 신드롬 정보(perfect error syndrome information) 및 논리 에러 부류(logic error class)를 획득하기 위해, 상기 실제 에러 신드롬 정보를 디코딩하는 단계 ―상기 논리 에러 부류는 상기 양자 회로에서 발생하는 에러의 맵핑을 통해 획득된 부류이고, 상기 퍼펙트 에러 신드롬 정보는 상기 양자 회로에 대해 무-잡음 에러 신드롬(noise-free error syndrome) 측정을 수행함으로써 획득된 정보임―; 및상기 논리 에러 부류 및 상기 퍼펙트 에러 신드롬 정보에 기반하여 상기 양자 회로의 에러 결과 정보를 결정하는 단계 ―상기 에러 결과 정보는 상기 양자 회로에서 에러가 발생하는 데이터 큐비트(data qubit) 및 대응하는 에러 부류를 지시하는 데 사용됨―를 포함하는, 양자 회로를 위한 결함 허용 및 에러 정정 디코딩 방법.양자 회로를 위한 결함 허용 및 에러 정정 디코딩 장치로서,양자 회로의 실제 에러 신드롬 정보를 획득하도록 구성된 신드롬 정보 획득 모듈 ―상기 실제 에러 신드롬 정보는 양자 에러 정정(QEC) 코드를 사용하여 상기 양자 회로에 대해 잡음 에러 신드롬 측정을 수행함으로써 획득된 정보임―;상기 실제 에러 신드롬 정보에 대응하는 퍼펙트 에러 신드롬 정보 및 논리 에러 부류를 획득하기 위해, 상기 실제 에러 신드롬 정보를 디코딩하도록 구성된 신드롬 정보 디코딩 모듈 ―상기 논리 에러 부류는 상기 양자 회로에서 발생하는 에러의 맵핑을 통해 획득된 부류이고, 상기 퍼펙트 에러 신드롬 정보는 상기 양자 회로에 대해 무-잡음 에러 신드롬 측정을 수행함으로써 획득된 정보임―; 및상기 논리 에러 부류 및 상기 퍼펙트 에러 신드롬 정보에 기반하여 상기 양자 회로의 에러 결과 정보를 결정하도록 구성된 에러 결과 결정 모듈 ―상기 에러 결과 정보는 상기 양자 회로에서 에러가 발생하는 데이터 큐비트 및 대응하는 에러 부류를 지시하는 데 사용됨―를 포함하는, 양자 회로를 위한 결함 허용 및 에러 정정 디코딩 장치.프로그래밍가능 논리 회로 및/또는 프로그램 명령들을 포함하는 칩으로서,상기 칩은, 제1항 내지 제13항 중 어느 한 항에 따른 양자 회로를 위한 결함 허용 및 에러 정정 디코딩 방법을 구현하기 위해 컴퓨터 디바이스 상에서 실행되도록 구성되는, 프로그래밍가능 논리 회로 및/또는 프로그램 명령들을 포함하는 칩.",
#         "application_date": "20210122",
#         "documentId": "kr20217035047a",
#         "application_number": "2021-7035047"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDA
# 현재 ZIP 폴더 총 파일 개수: 2031
# 현재 ZIP 폴더 JSON 파일 개수: 2031
# ['/jp2006163376b2.json', '/jp2002000785b2.json', '/jp2001081501a.json', '/jp2002059733a.json', '/jp2008203486b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2021",
#         "invention_title": "양자 얽힌 상태 정보를 결정하기 위한 장치 및 방법",
#         "ipc_section": "G",
#         "open_number": "2023-0108333",
#         "abstract": "양자 얽힌 상태 정보를 결정하기 위한 시스템은 복수의 제1 광자 및 복수의 제2 광자를 발생시키도록 구성된 얽힌 광자 소스를 포함하며, 제1 및 제2 광자들은 각각의 광자의 이용 가능한 양자 정보가 추가 양자 정보를 포함할 수 있도록 2개 이상의 베이스에서 얽힌다. 제1 수신기는 제1 순서화된 리스트의 상태 값들의 서브세트를 포함하는 제1 공유된 리스트를 발생시키고 제2 수신기는 제2 순서화된 리스트의 상태 값들의 서브세트를 포함하는 제2 공유된 리스트를 발생시킨다. 순서화된 리스트들은 타임 빈들, 타임 스탬프들 또는 차분 시간들일 수 있다. 수신기들은 성능 메트릭들을 달성하기 위해 측정 해상도를 변조한다. 프로세서는 제1 및 제2 공유된 리스트들을 비교하여 매칭 상태 값들을 식별하고 얽힌 양자 상태 정보를 유도한다. 얽힌 양자 상태 정보는 클록들을 동기화하거나, 에러들을 검출하거나, 공유된 비밀들을 발생시키기 위해 사용될 수 있다.",
#         "ipc_subclass": "G06N",
#         "applicant_name": "큐비트 무빙 앤드 스토리지, 엘엘씨",
#         "ipc_main": "G06N-010/40",
#         "ipc_all": "G06N-010/40|G06F-001/12|G06F-001/14|G06N-010/70|B82Y-010/00",
#         "ipc_class": "G06",
#         "claims": "양자 얽힌 상태 정보를 결정하기 위한 시스템으로서, 상기 시스템은,a) 제1 출력에서 복수의 제1 광자 및 제2 출력에서 복수의 제2 광자를 발생시키도록 구성된 얽힌 광자 소스로서, 상기 복수의 제1 광자 각각은 각각의 광자의 이용 가능한 양자 정보가 제1 기저, 제2 기저, 또는 제3 기저 중 임의의 2개에서 얽히는 광자들과 비교되는 추가 양자 정보를 포함하도록 제1 기저, 제2 기저, 및 제3 기저에서 상기 복수의 제2 광자 각각과 얽히는 얽힌 광자 소스;b) 상기 얽힌 광자 소스의 제1 출력에 결합된 입력을 갖는 제1 수신기로서, 상기 제1 수신기는 상기 복수의 제1 광자의 일부에 대한 상태 값들의 제1 순서화된 리스트를 발생시키도록 구성되고, 상기 상태 값들의 제1 순서화된 리스트는 상기 복수의 제1 광자의 일부의 각각의 광자가 도달 시간만큼 상기 제1 순서화된 리스트 내에 위치되는 상태 값들을 갖도록 조직되고 상기 제1 순서화된 리스트는 각각의 광자의 상기 제1 기저의 상태 값, 상기 제2 기저의 상태 값, 및 상기 제3 기저의 상태 값이 연관되도록 조직되고, 상기 제1 수신기는 적어도 상기 제1 순서화된 리스트의 상태 값들의 서브세트를 포함하는 제1 공유된 리스트를 발생시키도록 더 구성된 제1 수신기;c) 상기 얽힌 광자 소스의 제2 출력에 결합된 입력을 갖는 제2 수신기로서, 상기 제2 수신기는 상기 복수의 제2 광자의 일부에 대한 상태 값들의 제2 순서화된 리스트를 발생시키도록 구성되고, 상기 제2 순서화된 리스트는 상기 복수의 제2 광자의 일부의 각각의 광자가 도달 시간만큼 상기 제2 순서화된 리스트 내에 위치되는 상태 값들을 갖도록 조직되고 상기 제2 순서화된 리스트는 각각의 광자의 상기 제1 기저의 상태 값, 상기 제2 기저의 상태 값, 및 상기 제3 기저의 상태 값이 연관되도록 조직되고, 상기 제2 수신기는 적어도 상기 제2 순서화된 리스트의 상태 값들의 서브세트를 포함하는 제2 공유된 리스트를 발생시키도록 더 구성된 제2 수신기; 및d) 상기 제1 수신기의 출력에 결합된 제1 입력 및 상기 제2 수신기의 출력에 결합된 제2 입력을 갖는 프로세서를 포함하며, 상기 프로세서는 매칭 상태 값들을 식별하기 위해 생기 제1 공유된 리스트를 상기 제2 공유된 리스트와 비교하도록 구성되고 상기 프로세서는 상기 매칭 상태 값들로부터 얽힌 양자 상태 정보를 유도하도록 더 구성되며, 이에 따라 상기 제1 기저, 상기 제2 기저, 또는 상기 제3 기저 중 임의의 2개에서 얽히는 광자들과 비교되는 추가 양자 정보를 포함하는 매칭 상태 값들의 적어도 일부와 연관된 광자들의 이용 가능한 양자 정보를 사용하는, 양자 얽힌 상태 정보를 결정하기 위한 시스템.양자 얽힌 상태 정보를 결정하기 위한 시스템으로서, 상기 시스템은,a) 제1 출력에 복수의 제1 광자 및 제2 출력에 복수의 제2 광자를 발생시키도록 구성된 얽힌 광자 소스로서, 상기 복수의 제1 광자 각각은 시간 기저 및 다른 기저에서 상기 복수의 제2 광자 각각과 얽히는 얽힌 광자 소스;b) 상기 얽힌 광자 소스의 제1 출력에 결합된 입력을 갖는 제1 수신기로서, 상기 제1 수신기는 상기 복수의 제1 광자의 일부에 대한 다른 기저의 상태 값들의 제1 순서화된 리스트를 발생시키도록 구성되고, 상기 제1 수신기는 제1 순서화된 리스트에 기초하여 제1 공유된 타임 빈 콤을 발생시키도록 더 구성된 제1 수신기;c) 상기 얽힌 광자 소스의 제2 출력에 결합된 입력을 갖는 제2 수신기로서, 상기 제2 수신기는 상기 복수의 제2 광자의 일부에 대한 다른 기저의 상태 값들의 제2 순서화된 리스트를 발생시키도록 구성되고, 상기 제2 수신기는 제2 순서화된 리스트에 기초하여 제2 공유된 타임 빈 콤을 발생시키도록 더 구성된 제2 수신기; 및d) 상기 제1 수신기의 출력에 결합된 제1 입력 및 상기 제2 수신기의 출력에 결합된 제2 입력을 갖는 프로세서로서, 상기 프로세서는 얽힌 쌍들을 식별하기 위해 상기 제1 공유된 타임 빈 콤 및 상기 제2 공유된 타임 빈 콤을 비교하도록 구성되는 프로세서를 포함하는, 양자 얽힌 상태 정보를 결정하기 위한 시스템.양자 얽힌 상태 정보를 결정하기 위한 시스템으로서, 상기 시스템은,a) 제1 출력에 복수의 제1 광자 및 제2 출력에 복수의 제2 광자를 발생시키도록 구성된 얽힌 광자 소스로서, 상기 복수의 제1 광자 각각은 측정 해상도에 의해 결정되는 상태 차원을 포함하는 제1 기저에서 상기 복수의 제2 광자 각각과 얽히고 제2 기저에서 얽히는 얽힌 광자 소스;b) 상기 얽힌 광자 소스의 제1 출력에 결합된 입력을 갖는 제1 수신기로서, 상기 제1 수신기는 시간에 따라 변하는 제1 측정 해상도로 상기 제1 광자들의 제1 기저를 측정하도록 구성되고, 상기 복수의 제1 광자의 일부에 대한 측정된 제1 기저 및 대응하는 제2 기저의 상태 값들의 제1 리스트를 발생시키도록 더 구성되고, 상기 제1 수신기는 상기 상태 값들의 제1 리스트의 상태 값들의 서브세트를 포함하는 제1 공유된 리스트를 발생시키도록 더 구성된 제1 수신기;c) 상기 얽힌 광자 소스의 제2 출력에 결합된 입력을 갖는 제2 수신기로서, 상기 제2 수신기는 시간에 따라 변하는 제2 측정 해상도로 상기 제2 광자들의 제1 기저를 측정하도록 구성되고, 상기 복수의 제2 광자의 일부에 대한 측정된 제1 기저 및 대응하는 제2 기저의 상태 값들의 제2 리스트를 발생시키도록 더 구성되고, 상기 제2 수신기는 상기 상태 값들의 제2 리스트의 상태 값들의 서브세트를 포함하는 제2 공유된 리스트를 발생시키도록 더 구성된 제2 수신기; 및d) 상기 제1 수신기의 출력에 결합된 제1 입력 및 상기 제2 수신기의 출력에 결합된 제2 입력을 갖는 프로세서를 포함하며, 상기 프로세서는 얽힌 양자 상태 정보를 식별하기 위해 상기 제1 공유된 리스트 및 상기 제2 공유된 리스트를 비교하도록 구성되는, 양자 얽힌 상태 정보를 결정하기 위한 시스템.제1 및 제2 독립 클록 사이에서 공통 참조 시간을 결정하는 방법으로서, 상기 방법은,a) 복수의 제1 광자 및 복수의 제2 광자를 발생시키는 단계로서, 상기 복수의 제1 광자 및 상기 복수의 제2 광자 각각은 시간인 제1 기저에서 얽히고, 제1 및 제2 상태를 포함하는 제2 기저에서 얽히는 단계 ;b) 제1 클록에 의해 측정되는 각각의 도달 시간들에 의해 순서화되는 복수의 제1 광자의 측정된 복수의 상태 값의 제1 리스트를 결정하는 단계;c) 제2 클록에 의해 측정되는 각각의 도달 시간들에 의해 순서화되는 복수의 제2 광자의 측정된 복수의 상태 값의 제2 리스트를 결정하는 단계;d) 상기 제1 순서화된 리스트의 제2 기저 상태 값들의 서브세트를 상기 제2 순서화된 리스트의 제2 기저 상태 값들의 복수의 서브세트에 비교하는 단계;e) 상기 제2 순서화된 리스트의 복수의 서브세트 내에서 매칭 서브세트를 식별하는 단계로서, 상기 매칭 서브세트는 적어도 하나의 상태 값 및 적어도 하나의 상태 값과 매칭하는 대응하는 위치 및 상기 제1 순서화된 리스트의 서브세트 내의 대응하는 위치를 포함하는 단계;f) 상기 제2 순서화된 리스트의 매칭된 서브세트의 특정 위치 내의 상태 값들 중 하나와 연관된 도달 시간을 상기 제2 클록에 대한 초기 참조 시간으로서 식별하는 단계; 및g) 상기 제1 순서화된 리스트의 서브세트 내의 제2 순서화된 리스트의 매칭된 서브세트의 특정 위치를 갖는 제1 순서화된 리스트의 서브세트의 상태 값들 중 하나와 연관된 도달 시간을 상기 제1 클록에 대한 초기 참조 시간으로서 식별하는 단계를 포함하며, 상기 제1 클록에 대한 초기 참조 시간 및 상기 제2 클록에 대한 초기 참조 시간은 상기 제1 및 제2 클록들 사이에 공통 시간 참조를 설정하는, 방법.제1 및 제2 클록을 동기화하는 방법으로서, 상기 방법은,a) 단일 광자들의 측정된 상태 값들의 제1 및 제2 리스트를 비교함으로써 광자들의 얽힌 쌍들을 식별하는 단계로서, 상기 제1 리스트는 제1 클록을 사용하여 측정되는 광자 도달 시간들에 의해 컴파일되고 상기 제2 리스트는 제2 클록을 사용하여 측 ...
#         "application_date": "20211123",
#         "documentId": "kr20237021036a",
#         "application_number": "2023-7021036"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCA
# 현재 ZIP 폴더 총 파일 개수: 3480
# 현재 ZIP 폴더 JSON 파일 개수: 3480
# ['/jp2015120623a.json', '/jp2015160590b2.json', '/jp2017523189b2.json', '/jp2015052138b2.json', '/jp2014049916b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2023",
#         "invention_title": "자가 진단 연계 건강 기록 관리 방법 및 이를 통한 의료 정보 서비스 제공 플랫폼",
#         "ipc_section": "G",
#         "open_number": "2023-0049592",
#         "abstract": "본 발명은 의료 정보의 표준화 및 이를 통한 의료 정보의 통합 방법에 관한 것이다. 본 발명의 일실시예에 따른 이종 의료 데이터 기반 FHIR 리소스 생성 방법은 수집된 이종의 의료 정보 내 데이터의 필드명 및 필드값을 추출하는 단계; 상기 추출된 필드명의 유사도를 판단하고, 상기 유사도에 따라 상기 필드명과 FHIR(Fast Healthcare Interoperability Resources) 표준 항목간의 매핑 규칙을 정의하는 단계; 및 상기 정의된 매핑 규칙에 따라 상기 필드 값들을 저장하는 단계를 포함하는 것을 특징으로 하고, 상기 필드명과 표준 항목간의 매핑 규칙이 미정의된 경우 상기 필드값의 유사도를 판단하여, 상기 필드명을 표준 항목에 매핑시키는 것이 바람직하다. 본 발명에 따르면 FHIR의 표준에 맞는 의료 정보의 매핑을 통해 다양한 양식의 의료 정보를 표준화하고 이를 통해 빅데이터 기반의 의료 서비스를 제공할 수 있다.",
#         "ipc_subclass": "G16H",
#         "applicant_name": "(주)미라벨소프트",
#         "ipc_main": "G16H-010/60",
#         "ipc_all": "G16H-010/60|A61B-005/00|A61B-005/021|G06N-003/08|G16H-070/00",
#         "ipc_class": "G16",
#         "claims": "서버에서 수행되는 자가 진단 연계 건강 기록 관리 방법에 있어서,수집된 이종의 의료 정보 내 데이터의 필드명 및 필드값을 추출하는 단계;상기 추출된 필드명의 유사도를 판단하고, 상기 유사도에 따라 상기 필드명과 표준 항목간의 매핑 규칙을 정의하는 단계; 및상기 정의된 매핑 규칙에 따라 상기 필드 값들을 저장하는 단계를 포함하는 것을 특징으로 하고,상기 필드명과 표준 항목간의 매핑 규칙이 미정의된 경우 상기 필드값의 유사도를 판단하여 상기 필드명을 표준 항목에 매핑시키되,상기 의료 정보는 개인 건강 기록(PHR:Personal Health Record)을 포함하고,상기 개인 건강 기록은, EMR 기반의 제1 개인 건강 기록과 환자 개인의 자가 진단에 따른 제2 개인 건강 기록으로 구분되며,제2 개인 건강 기록은 제1 개인 건강 기록에 따른 신뢰도를 이용하여 조정되는 것을 특징으로 하는 자가 진단 연계 건강 기록 관리 방법.의료 정보를 수집하는 의료 정보 수집부;수집된 이종의 의료 정보 내 데이터의 필드명 및 필드값을 추출하고, 신경망을 이용하여 미리 결정된 제1 계층 항목과 상기 추출된 필드명의 특징 정보 간의 유사도를 판단하고, 상기 유사도에 따라 상기 필드명과 표준 항목간의 매핑 규칙을 정의하는 의료 정보 특징 추출부; 상기 정의된 매핑 규칙을 저장하는 매핑 규칙 저장부; 및상기 매핑 규칙에 따라 생성된 리소스를 제공하는 데이터 제공부를 포함하는 것을 특징으로 하고,상기 의료 정보 특징 추출부는 필드명과 표준 항목간의 매핑 규칙이 미정의된 경우 상기 필드값의 유사도를 판단하여 상기 필드명을 표준 항목에 매핑시키되,상기 의료 정보는 개인 건강 기록(PHR:Personal Health Record)을 포함하고,상기 개인 건강 기록은, EMR 기반의 제1 개인 건강 기록과 환자 개인의 자가 진단에 따른 제2 개인 건강 기록으로 구분되며,제2 개인 건강 기록은 제1 개인 건강 기록에 따른 신뢰도를 이용하여 조정되는 것을 특징으로 하는 이종 의료 데이터 기반 FHIR 리소스 생성 서버.제 1 항에 따른 자가 진단 연계 건강 기록 관리 방법을 수행하는 컴퓨터 판독가능한 기록 매체에 저장된 프로그램.",
#         "application_date": "20230329",
#         "documentId": "kr20230041193a",
#         "application_number": "2023-0041193"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCB
# 현재 ZIP 폴더 총 파일 개수: 431
# 현재 ZIP 폴더 JSON 파일 개수: 431
# ['/jp2015021142b2.json', '/jp2013531516b2.json', '/jp2020515955b2.json', '/jp2002354364a.json', '/jp2019561982b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2022",
#         "invention_title": "원생 시스템을 기반으로 한 파생 소프트웨어 구축 방법, 시스템 및 설비",
#         "ipc_section": "G",
#         "open_number": "2023-0088686",
#         "abstract": "본 발명은 소프트웨어 파생 기술분야에 속하고, 상세하게, 원생 시스템(proto system)을 기반으로 한 파생 소프트웨어 구축 방법, 시스템 및 설비에 관한 것이며, 여기에서, 원생 시스템을 기반으로 한 파생 소프트웨어 구축 방법은 아래와 같이, 파생 소프트웨어의 사용자 인터페이스를 편집하여 파생 소프트웨어의 인터페이스 구성 파일로 저장하는 단계; 및 파생 소프트웨어의 인터페이스 구성 파일에 근거해 사용자가 설계한 인터페이스를 생성하는 단계;를 포함하며, 따라서, 소프트웨어 플랫폼이 뒤이어 사용자모듈을 로딩하는 과정에서 상이한 사용자모듈의 종속항목을 구별하여 필요한 커널모듈을 선택적으로 로딩할 수 있어, 시스템의 CPU 및 메모리 소모를 줄이고 사용자가 소프트웨어 플랫폼을 사용하는 효율을 향상한다.",
#         "ipc_subclass": "G06F",
#         "applicant_name": "상하이 토선 테크놀로지 리미티드",
#         "ipc_main": "G06F-008/38",
#         "ipc_all": "G06F-008/38|G06F-009/445",
#         "ipc_class": "G06",
#         "claims": "원생 시스템(proto system)을 기반으로 한 파생 소프트웨어 구축 방법에 있어서,파생 소프트웨어의 사용자 인터페이스를 편집하여 파생 소프트웨어의 인터페이스 구성 파일로 저장하는 단계; 및파생 소프트웨어의 인터페이스 구성 파일에 근거해 사용자가 설계한 인터페이스를 생성하는 단계;를 포함하는 것을 특징으로 하는 원생 시스템을 기반으로 한 파생 소프트웨어 구축 방법.원생 시스템을 기반으로 한 파생 소프트웨어 구축 시스템에 있어서,파생 소프트웨어의 사용자 인터페이스를 편집하여 파생 소프트웨어의 인터페이스 구성 파일로 저장하는 편집모듈; 및파생 소프트웨어의 인터페이스 구성 파일에 근거해 사용자가 설계한 인터페이스를 생성하는 인터페이스 생성모듈;을 포함하는 것을 특징으로 하는 원생 시스템을 기반으로 한 파생 소프트웨어 구축 시스템.파생 소프트웨어 설비에 있어서,소프트웨어 플랫폼 커널모듈, 파생 소프트웨어 관리모듈, 파생 소프트웨어 디스플레이모듈을 포함하고;상기 소프트웨어 플랫폼 커널모듈은 상기 파생 소프트웨어 관리모듈을 제어해 파생 소프트웨어의 사용자 인터페이스를 편집하여 파생 소프트웨어의 인터페이스 구성 파일로 저장하는 데 적용하며;상기 소프트웨어 플랫폼 커널모듈은 상기 파생 소프트웨어 디스플레이모듈을 제어해 파생 소프트웨어의 인터페이스 구성 파일에 근거하여 사용자가 설계한 인터페이스를 생성하는 데 적용하는 것을 특징으로 하는 파생 소프트웨어 설비.",
#         "application_date": "20220905",
#         "documentId": "kr20237011068a",
#         "application_number": "2023-7011068"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCC
# 현재 ZIP 폴더 총 파일 개수: 456
# 현재 ZIP 폴더 JSON 파일 개수: 456
# ['/jp2002191652b2.json', '/jp2018036949a.json', '/kr20180033085b1.json', '/jp2022580326a.json', '/jp2018233018b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "application_year": "2023",
#         "invention_title": "인공지능 기반의 팀 매칭을 위한 게임 관리 서버, 방법 및 프로그램",
#         "ipc_section": "A",
#         "register_date": "20230426",
#         "abstract": "본 개시는 게임 정보를 제공하는 게임 서버와 통신을 수행하는 통신부; 및 인공지능 기반의 팀(Team) 자동 매칭과 관련된 동작을 제어하는 프로세서; 를 포함하고, 프로세서는, 통신부를 통해 게임 서버로부터 게임 정보를 수신받고, 게임 정보 내의 참여자의 속성 정보를 확인하며, 참여자의 속성 정보를 인공지능 모델을 기반으로 학습하여 분석하고, 참여자의 속성 정보에 연계되어 저장된 팀 매칭 정보를 추출하며, 추출된 팀 매칭 정보를 기반으로 자동 매칭되도록, 해당 팀 매칭 정보를 게임 서버로 전송하는 것을 특징으로 할 수 있다.",
#         "ipc_subclass": "A63F",
#         "applicant_name": "주식회사 오피지지",
#         "ipc_main": "A63F-013/795",
#         "register_year": "2023",
#         "ipc_all": "A63F-013/795|A63F-013/35|G06N-020/00|G06Q-050/10",
#         "ipc_class": "A63",
#         "claims": "게임 정보를 제공하는 게임 서버와 통신을 수행하는 통신부; 및인공지능 기반의 팀(Team) 매칭과 관련된 동작을 제어하는 프로세서; 를 포함하고,상기 프로세서는,상기 통신부를 통해 상기 게임 서버로부터 상기 게임 정보를 수신받고, 상기 게임 정보 내의 참여자의 속성 정보를 확인하며,상기 참여자의 속성 정보를 인공지능 모델을 기반으로 학습하여 분석하고,상기 참여자의 속성 정보 내의 전적 정보에 연계되어 저장된 제1 팀 매칭 정보를 추출하며,상기 참여자의 속성 정보 내의 성별 정보에 연계되어 저장된 제3 팀 매칭 정보를 추출하고,상기 참여자의 속성 정보 내의 게임 선호 포지션 이력 정보, 캐릭터 이력 정보, 행동 이력 정보, 게임 지속 시간 이력 정보, 연승 및 연패 이력 정보, 승률이 높은 시간대 이력 정보에 연계되어 저장된 제5 팀 매칭 정보를 추출하며,상기 추출된 제1 팀 매칭 정보, 상기 추출된 제3 팀 매칭 정보, 상기 추출된 제5 팀 매칭 정보를 기반으로 팀 재매칭되도록, 상기 제1 팀 매칭 정보, 상기 제3 팀 매칭 정보 및 상기 제5 팀 매칭 정보 기반의 팀 재매칭 정보를 상기 게임 서버로 전송하는 것을 특징으로 하는, 인공지능 기반의 팀 매칭을 위한 게임 관리 서버.게임 관리 서버에 의해 수행되는 인공지능 기반의 팀 매칭 방법에 있어서,게임 서버로부터 게임 정보를 수신받는 단계;상기 게임 정보 내의 참여자의 속성 정보를 확인하는 단계;상기 참여자의 속성 정보를 인공지능 모델을 기반으로 학습하여 분석하는 단계;상기 참여자의 속성 정보 내의 전적 정보에 연계되어 저장된 제1 팀 매칭 정보를 추출하는 단계;상기 참여자의 속성 정보 내의 성별 정보에 연계되어 저장된 제3 팀 매칭 정보를 추출하는 단계; 상기 참여자의 속성 정보 내의 게임 선호 포지션 이력 정보, 캐릭터 이력 정보, 행동 이력 정보, 게임 지속 시간 이력 정보, 연승 및 연패 이력 정보, 승률이 높은 시간대 이력 정보에 연계되어 저장된 제5 팀 매칭 정보를 추출하는 단계; 및상기 추출된 제1 팀 매칭 정보, 상기 추출된 제3 팀 매칭 정보, 상기 추출된 제5 팀 매칭 정보를 기반으로 팀 재매칭되도록, 상기 제1 팀 매칭 정보, 상기 제3 팀 매칭 정보 및 상기 제5 팀 매칭 정보 기반의 팀 재매칭 정보를 상기 게임 서버로 전송하는 단계; 를 포함하는, 방법.",
#         "application_date": "20230206",
#         "register_number": "2527558",
#         "documentId": "kr20230015320b1",
#         "application_number": "2023-0015320"
#     }
# }
#
# 총 데이터셋 개수: 22103
# {'dataset': {'application_year': '2002', 'invention_title': '인공지능 애플리케이션을 위한 음례를 선택하는 적응형 샘플링 수법', 'ipc_section': 'G', 'abstract': '인공지능 애플리케이션은 정례 및 음례를 포함한 훈련 세트한 이용을 필요로 한다. 음례는 특징 공간에서 우위인 특징에 관해서 정례의 분포를 이용하여 선택된다. 음례는 특징 공간에서 우위인 특징의 값을 상기 정례와 공유하는 또는 대략 공유한다. 이 타입의 훈련 세트가, 콘텐트리코멘다, 특히 텔레비젼 프로그램에 대한 리코멘다에 관해서 설명된다.', 'ipc_subclass': 'G06N', 'applicant_name': '코닌크렉카 필립스 엘렉트로닉스 N 비', 'ipc_main': 'G06N-005/04', 'ipc_all': 'G06N-005/04', 'ipc_class': 'G06', 'claims': '정례 및 음례를 가지는 훈련 세트한 이용을 필요로 하는 인공지능 애플리케이션을 실행하도록 구성된 처리 장치로서,데이터 및/또는 명령을 저장하도록 구성된 적어도 1개의 메모리와,상기 적어도 1개의 메모리를 이용하여, 훈련을 위한 정례 세트를 인식해 유지하는 조작, 및 상기 정례 세트에 따라 훈련을 위한 음례 세트를 선택하는 조작을 실행하도록 구성된 적어도 1개의 프로세서와,를 가지는 처리 장치.정례 및 음례를 가지는 훈련 세트한 이용을 필요로 하는, 콘텐츠를 추천하는 방법으로서,훈련을 위한 정례 세트를 인식해 유지하는 단계와,상기 정례 세트에 따라 훈련을 위한 음례 세트를 선택하는 단계와,를 가지는 방법.컴퓨터 프로그램으로서, 상기 컴퓨터 프로그램을 실행했을 때에, 프로그램 가능인 기기가 청구항 1 내지 8의 어느 한 항에 기재된 장치로서 기능하는 것을 가능하게 하는 컴퓨터 프로그램.', 'application_date': '20020325', 'documentId': 'jp2002578212a', 'application_number': '2002-578212'}}

# %% [markdown]
# raw: 22103

# %% [markdown]
# ## LABEL 데이터셋 확인

# %%
for zip_file in os.listdir(label_dataset_folder):
    
    zip_file_path = os.path.join(label_dataset_folder, zip_file)
    middle_code = zip_file_path.split("_")[7]
    print("국가중점기술분류 중분류코드:", middle_code)

    with zipfile.ZipFile(zip_file_path, "r") as label_zip_file:
        json_files = [
            file_name
            for file_name in label_zip_file.namelist()
            if file_name.endswith(".json")
        ]
        print("현재 ZIP 폴더 총 파일 개수:", len(label_zip_file.namelist()))
        print("현재 ZIP 폴더 JSON 파일 개수:", len(json_files))
        print(json_files[:5])
        print()
# Out:
# 국가중점기술분류 중분류코드: CDB
# 현재 ZIP 폴더 총 파일 개수: 3455
# 현재 ZIP 폴더 JSON 파일 개수: 3455
# ['/jp2006025142b2.json', '/jp2005067119a.json', '/jp2003509763a.json', '/jp2003306707a.json', '/jp2006515272b2.json']
#
# 국가중점기술분류 중분류코드: CCC
# 현재 ZIP 폴더 총 파일 개수: 3641
# 현재 ZIP 폴더 JSON 파일 개수: 3641
# ['/jp2000128642a.json', '/jp2015148120b2.json', '/jp2015087944b2.json', '/jp2006536533a.json', '/jp2010283389b2.json']
#
# 국가중점기술분류 중분류코드: CCA
# 현재 ZIP 폴더 총 파일 개수: 3480
# 현재 ZIP 폴더 JSON 파일 개수: 3480
# ['/jp2013085371b2.json', '/jp2014051114b2.json', '/jp2014049919b2.json', '/jp2014041785b2.json', '/jp2016519468b2.json']
#
# 국가중점기술분류 중분류코드: CCB
# 현재 ZIP 폴더 총 파일 개수: 3453
# 현재 ZIP 폴더 JSON 파일 개수: 3453
# ['/jp2010538226b2.json', '/jp2010015567b2.json', '/jp2002509189a.json', '/jp2001533509a.json', '/jp2009243394a.json']
#
# 국가중점기술분류 중분류코드: CDC
# 현재 ZIP 폴더 총 파일 개수: 3588
# 현재 ZIP 폴더 JSON 파일 개수: 3588
# ['/jp2015032905b2.json', '/jp2014110103b2.json', '/jp2015007037b2.json', '/jp2015118878b1.json', '/jp2015104975b2.json']
#
# 국가중점기술분류 중분류코드: CDA
# 현재 ZIP 폴더 총 파일 개수: 2031
# 현재 ZIP 폴더 JSON 파일 개수: 2031
# ['/jp2001081501a.json', '/jp2002523392a.json', '/jp2008527629b2.json', '/jp2002271473b2.json', '/jp2002059733a.json']

# %%
# RAW 데이터셋을 하나의 리스트로 모으기

label_dataset_list = []

for zip_file in os.listdir(label_dataset_folder):
    
    zip_file_path = os.path.join(label_dataset_folder, zip_file)
    # print(zip_file_path)
    middle_code = zip_file_path.split("_")[7]
    print("국가중점기술분류 중분류코드:", middle_code)

    with zipfile.ZipFile(zip_file_path, "r") as label_zip_file:
        json_files = [
            file_name
            for file_name in label_zip_file.namelist()
            if file_name.endswith(".json")
        ]
        print("현재 ZIP 폴더 총 파일 개수:", len(label_zip_file.namelist()))
        print("현재 ZIP 폴더 JSON 파일 개수:", len(json_files))
        print(json_files[:5])
        print("예시 JSON 파일 내용:")

        for json_file in json_files:
            with label_zip_file.open(json_file, "r") as example:
                json_example = example.read().decode("utf-8")
        
            data = json.loads(json_example)
            # label 데이터셋 리스트에 추가하기
            label_dataset_list.append(data)

        print(json.dumps(data, indent=4, ensure_ascii=False))
        print()

print("총 데이터셋 개수:", len(label_dataset_list))
print(label_dataset_list[0])
# Out:
# 국가중점기술분류 중분류코드: CDB
# 현재 ZIP 폴더 총 파일 개수: 3455
# 현재 ZIP 폴더 JSON 파일 개수: 3455
# ['/jp2006025142b2.json', '/jp2005067119a.json', '/jp2003509763a.json', '/jp2003306707a.json', '/jp2006515272b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "신개념 컴퓨팅 기술",
#         "Mtext": "컴퓨팅·소프트웨어",
#         "Lno": "C",
#         "ipc_main": "H04L-009/00",
#         "Mno": "CD",
#         "country_code": "KR",
#         "Sno": "CDB",
#         "documentId": "kr20237024479a",
#         "application_number": "2023-7024479",
#         "Ltext": "ICT·SW",
#         "keyword": "컴퓨팅/암호/결합/회로/비밀/엘리먼트/기타",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCC
# 현재 ZIP 폴더 총 파일 개수: 3641
# 현재 ZIP 폴더 JSON 파일 개수: 3641
# ['/jp2000128642a.json', '/jp2015148120b2.json', '/jp2015087944b2.json', '/jp2006536533a.json', '/jp2010283389b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "다중 인공지능 공통 플랫폼 기술",
#         "Mtext": "빅데이터·인공지능",
#         "Lno": "C",
#         "ipc_main": "G06Q-050/20",
#         "Mno": "CC",
#         "country_code": "KR",
#         "Sno": "CCC",
#         "documentId": "kr20230051156a",
#         "application_number": "2023-0051156",
#         "Ltext": "ICT·SW",
#         "keyword": "인공지능/확률/예측/추천/진단/매칭/인공지능",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCA
# 현재 ZIP 폴더 총 파일 개수: 3480
# 현재 ZIP 폴더 JSON 파일 개수: 3480
# ['/jp2013085371b2.json', '/jp2014051114b2.json', '/jp2014049919b2.json', '/jp2014041785b2.json', '/jp2016519468b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "지능형 빅데이터 분석 및 활용 기술",
#         "Mtext": "빅데이터·인공지능",
#         "Lno": "C",
#         "ipc_main": "H04H-020/33",
#         "Mno": "CC",
#         "country_code": "KR",
#         "Sno": "CCA",
#         "documentId": "kr20230093136a",
#         "application_number": "2023-0093136",
#         "Ltext": "ICT·SW",
#         "keyword": "방송/정보처리/스피커/변환/센서/IoT/기타",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDB
# 현재 ZIP 폴더 총 파일 개수: 432
# 현재 ZIP 폴더 JSON 파일 개수: 432
# ['/jp2014262065b2.json', '/jp2015516152b2.json', '/jp2017549621a.json', '/jp2004153812b2.json', '/jp2016047044a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "신개념 컴퓨팅 기술",
#         "Mtext": "컴퓨팅·소프트웨어",
#         "Lno": "C",
#         "ipc_main": "G11C-011/08",
#         "Mno": "CD",
#         "country_code": "KR",
#         "Sno": "CDB",
#         "documentId": "kr20220024578a",
#         "application_number": "2022-0024578",
#         "Ltext": "ICT·SW",
#         "keyword": "컴퓨팅/배치/타겟/캐비티/소자/안테나/기타",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCB
# 현재 ZIP 폴더 총 파일 개수: 3453
# 현재 ZIP 폴더 JSON 파일 개수: 3453
# ['/jp2010538226b2.json', '/jp2010015567b2.json', '/jp2002509189a.json', '/jp2001533509a.json', '/jp2009243394a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "초고속·대용량 데이터 플랫폼 기술",
#         "Mtext": "빅데이터·인공지능",
#         "Lno": "C",
#         "ipc_main": "G06N-010/40",
#         "Mno": "CC",
#         "country_code": "KR",
#         "Sno": "CCB",
#         "documentId": "kr20237020119a",
#         "application_number": "2023-7020119",
#         "Ltext": "ICT·SW",
#         "keyword": "선형/큐비트/비트/에너지/양자/초전도/기타",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDC
# 현재 ZIP 폴더 총 파일 개수: 3588
# 현재 ZIP 폴더 JSON 파일 개수: 3588
# ['/jp2015032905b2.json', '/jp2014110103b2.json', '/jp2015007037b2.json', '/jp2015118878b1.json', '/jp2015104975b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "시스템 SW 운영 및 기반 기술",
#         "Mtext": "컴퓨팅·소프트웨어",
#         "Lno": "C",
#         "ipc_main": "G03F-007/20",
#         "Mno": "CD",
#         "country_code": "KR",
#         "Sno": "CDC",
#         "documentId": "kr20237023737a",
#         "application_number": "2023-7023737",
#         "Ltext": "ICT·SW",
#         "keyword": "적응/시스템/메모리/파일/서버/단계/기타",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDC
# 현재 ZIP 폴더 총 파일 개수: 451
# 현재 ZIP 폴더 JSON 파일 개수: 451
# ['/jp2016537764b2.json', '/jp2016171755b2.json', '/jp2015148554b2.json', '/jp2022097494a.json', '/jp2020195475a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "시스템 SW 운영 및 기반 기술",
#         "Mtext": "컴퓨팅·소프트웨어",
#         "Lno": "C",
#         "ipc_main": "G06F-008/41",
#         "Mno": "CD",
#         "country_code": "KR",
#         "Sno": "CDC",
#         "documentId": "kr20217037436a",
#         "application_number": "2021-7037436",
#         "Ltext": "ICT·SW",
#         "keyword": "통합/자동화/수정/변수/파일/타겟/기타",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCB
# 현재 ZIP 폴더 총 파일 개수: 431
# 현재 ZIP 폴더 JSON 파일 개수: 431
# ['/jp2020517377a.json', '/jp2011239336b1.json', '/jp2019561982b2.json', '/jp2012503493b2.json', '/jp2013531516b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "초고속·대용량 데이터 플랫폼 기술",
#         "Mtext": "빅데이터·인공지능",
#         "Lno": "C",
#         "ipc_main": "G06F-008/35",
#         "Mno": "CC",
#         "country_code": "KR",
#         "Sno": "CCB",
#         "documentId": "kr20237011067a",
#         "application_number": "2023-7011067",
#         "Ltext": "ICT·SW",
#         "keyword": "상호 호출/함수/공유/라이브러리/소프트웨어/플랫폼/기타",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDA
# 현재 ZIP 폴더 총 파일 개수: 249
# 현재 ZIP 폴더 JSON 파일 개수: 249
# ['/jp2021562774a.json', '/jp2018536473b2.json', '/jp2021078050a.json', '/jp2006519164b2.json', '/jp2021158888a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "양자정보통신 기술",
#         "Mtext": "컴퓨팅·소프트웨어",
#         "Lno": "C",
#         "ipc_main": "G06N-010/60",
#         "Mno": "CD",
#         "country_code": "KR",
#         "Sno": "CDA",
#         "documentId": "kr20237024872a",
#         "application_number": "2023-7024872",
#         "Ltext": "ICT·SW",
#         "keyword": "양자/함수/혼합/파라미터/상태/측정/양자",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CDA
# 현재 ZIP 폴더 총 파일 개수: 2031
# 현재 ZIP 폴더 JSON 파일 개수: 2031
# ['/jp2001081501a.json', '/jp2002523392a.json', '/jp2008527629b2.json', '/jp2002271473b2.json', '/jp2002059733a.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "양자정보통신 기술",
#         "Mtext": "컴퓨팅·소프트웨어",
#         "Lno": "C",
#         "ipc_main": "H04N-019/13",
#         "Mno": "CD",
#         "country_code": "KR",
#         "Sno": "CDA",
#         "documentId": "kr20237022958a",
#         "application_number": "2023-7022958",
#         "Ltext": "ICT·SW",
#         "keyword": "양자/계수/효율/코딩/변환/디코딩/양자",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCC
# 현재 ZIP 폴더 총 파일 개수: 456
# 현재 ZIP 폴더 JSON 파일 개수: 456
# ['/jp2021537198b2.json', '/jp2018036949a.json', '/jp2016215529a.json', '/jp2017030552a.json', '/jp2018233018b2.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "다중 인공지능 공통 플랫폼 기술",
#         "Mtext": "빅데이터·인공지능",
#         "Lno": "C",
#         "ipc_main": "G06Q-050/20",
#         "Mno": "CC",
#         "country_code": "KR",
#         "Sno": "CCC",
#         "documentId": "kr20230072407a",
#         "application_number": "2023-0072407",
#         "Ltext": "ICT·SW",
#         "keyword": "카메라/서버/인공지능/시험/인식/온라인/인공지능",
#         "document_type": "A"
#     }
# }
#
# 국가중점기술분류 중분류코드: CCA
# 현재 ZIP 폴더 총 파일 개수: 436
# 현재 ZIP 폴더 JSON 파일 개수: 436
# ['/jp2016519729b2.json', '/jp2016148348b2.json', '/jp2014051596b2.json', '/jp2021083911b1.json', '/kr20150190440b1.json']
# 예시 JSON 파일 내용:
# {
#     "dataset": {
#         "updateDate": "20240207",
#         "Stext": "지능형 빅데이터 분석 및 활용 기술",
#         "Mtext": "빅데이터·인공지능",
#         "Lno": "C",
#         "ipc_main": "G06F-016/21",
#         "Mno": "CC",
#         "country_code": "KR",
#         "Sno": "CCA",
#         "documentId": "kr20220148725a",
#         "application_number": "2022-0148725",
#         "Ltext": "ICT·SW",
#         "keyword": "빅데이터/인터페이스/인덱스/명령어/데이터 저장/데이터베이스/기타",
#         "document_type": "A"
#     }
# }
#
# 총 데이터셋 개수: 22103
# {'dataset': {'updateDate': '20240207', 'Stext': '신개념 컴퓨팅 기술', 'Mtext': '컴퓨팅·소프트웨어', 'Lno': 'C', 'ipc_main': 'G06F-009/50', 'Mno': 'CD', 'country_code': 'JP', 'Sno': 'CDB', 'documentId': 'jp2006025142b2', 'application_number': '2006-025142', 'Ltext': 'ICT·SW', 'keyword': '컴퓨터/접속/서비스/노드/태스크/병렬/기타', 'document_type': 'B2'}}

# %%
# RAW, LABEL 저장하기
total_raw_json_path = os.path.join(dataset_path, "total_raw.json")
total_label_json_path = os.path.join(dataset_path, "total_label.json")

raw_json = json.dumps(raw_dataset_list, indent=4, ensure_ascii=False)
with open(total_raw_json_path, "w", encoding="utf-8") as f:
    f.write(raw_json)
    
label_json = json.dumps(label_dataset_list, indent=4, ensure_ascii=False)
with open(total_label_json_path, "w", encoding="utf-8") as f:
    f.write(label_json)

# %% [markdown]
# ```
# {
#       // Metadata 용
#       "register_year": "등록연도",
#       "register_month": "등록월",
#       "register_day": "등록일",
#       "regitster_number": "등록번호",
#
#       "application_year": "출원연도",
#       "application_month": "출원월",
#       "application_day": "출원일",
#       "application_number": "출원번호",
#
#       "open_year": "공개연도",
#       "open_month": "공개월",
#       "open_day": "공개일",
#       "open_number": "공개번호",
#
#       "ipc_section": "IPC-Section",
#       "ipc_class": "IPC-Class",
#       "ipc_subclass": "IPC-Subclass",
#       "ipc_maingroup": "IPC-MainGroup",
#
#       "large_no": "대분류코드",
#       "middle_no": "중분류코드",
#       "small_no": "소분류코드",
#
#       "country_code": "국가코드",
#       "document_id": "문헌키",
#       "document_type": "문헌타입",
#
#       // 임베딩용
#       "invention_title": "발명의명칭",
#       "inventor_name": "발명자명",
#       "applicant_name": "출원인명",
#       "claims": "청구항",
#       "abstract": "요약",
#       "keyword": "명칭, 요약, 청구항에서 추출한 키워드 6개 및 국가전략기술 12대 분야 대분류 1개 (리스트 형태로 저장: /로 split하기)"
#     }
# ```

# %%
base_format = {
    "register_year": None,
    "register_month": None,
    "register_day": None,
    "regitster_number": None,
    
    "application_year": None,
    "application_month": None,
    "application_day": None,
    "application_number": None,
    
    "open_year": None,
    "open_month": None,
    "open_day": None,
    "open_number": None,
    
    "ipc_all": None,
    "ipc_section": None,
    "ipc_class": None,
    "ipc_subclass": None,
    "ipc_maingroup": None,

    "large_no": None,
    "middle_no": None,
    "small_no": None,

    "country_code": None,
    "document_id": None,
    "document_type": None,
    
    # embedding을 위한 키값들
    "invention_title": None,
    "inventor_name": None,
    "applicant_name": None,
    "claims": None,
    "abstract": None,
    "keyword": [],

    # 진짜 embedding 할 내용
    "invention_info": None
}

# %% [markdown]
# ```
# "dataset": {
#         "application_year": "2023",
#         "invention_title": "인공지능에 기반한 최적 광고 추천 시스템",
#         "ipc_section": "G",
#         "register_date": "20230721",
#         "abstract": "일실시예에 따르면, 인공지능에 기반한 최적 광고 추천 시스템에 있어서, 인공지능에 기반한 최적 광고를 추천하는 서버를 포함하는 시스템이 제공된다.",
#         "ipc_subclass": "G06Q",
#         "applicant_name": "그린브릭스컴퍼니 주식회사",
#         "ipc_main": "G06Q-030/02",
#         "register_year": "2023",
#         "ipc_all": "G06Q-030/02|G06N-003/0442|G06N-003/045|G06N-003/0464|G06N-003/0475|G06N-003/08|G06N-003/094",
#         "ipc_class": "G06",
#         "claims": "인공지능에 기반한 최적 광고 추천 시스템에 있어서,인공지능에 기반한 광고를 추천하는 서버를 포함하고,상기 서버는,데이터 수집부;데이터 분석부; 및광고 추천부를 포함하고,상기 데이터 수집부는,소정의 검색 포털 사이트 서버를 통해, 상기 검색 포털 사이트의 소정의 광고 위치에 디스플레이된 광고 데이터인 제1 데이터를 주기적으로 수집하되, 상기 제1 데이터는 광고 콘텐츠, 디스플레이 기간, 노출수, CTR(Click Through Rate: 클릭률), CVR(ConVersion Rate: 전환율), CPA(Cost Per Action: 전환당 비용), 및 랜딩 페이지 데이터를 포함하고,상기 데이터 분석부는,상기 제1 데이터의 디스플레이 기간과 노출수 및 CPA(전환당 비용)를 입력 데이터로, 시간대별, 요일별, 월별 예상 노출수 및 시간대별 예상 CPA를 예측하도록 제1 인공지능 모델을 학습시키되, 상기 제1 인공지능 모델은 LSTM(Long Short-Term Memory) 모델 또는 Prophet 모델이고,상기 제1 인공지능 모델이 예측한, 시간대별, 요일별, 월별 예상 노출수 및 상기 시간대별 예상 CPA를 Tableau, Microsoft Power BI, Google Data Studio 중 어느 하나의 도구를 이용하여 시각화하고,CTR(클릭률)이 1% 이상인 제1 데이터의 광고 콘텐츠를 입력 데이터로, 새로운 광고 콘텐츠를 생성하도록 제2 인공지능 모델을 학습시키되, 상기 제2 인공지능 모델은 GAN(Generative Adversarial Network) 모델이고,CVR(전환율)이 5% 이상인 제1 데이터의 랜딩 페이지 데이터를 입력 데이터로, 새로운 랜딩 페이지를 생성하도록 제3 인공지능 모델을 학습시키되, 상기 제3 인공지능 모델은 GAN(Generative Adversarial Network) 모델이고,상기 제1 인공지능 모델 내지 제3 인공지능 모델은,주기적으로 수집되는 제1 데이터에 따라 주기적으로 추가 학습되고,상기 데이터 수집부는,광고주 단말을 통해 입력된, 광고 상품의 랜딩 페이지로 사용될 웹 페이지 주소를 기반으로, 상기 웹 페이지 데이터인 제2 데이터를 수집하고,상기 데이터 분석부는,이미지와 텍스트를 분석하도록 기학습된 제4 인공지능 모델에, 상기 제2 데이터를 입력하여 상기 광고 상품의 정보를 획득하되, 상기 제4 인공지능 모델은, Faster R-CNN 또는 YOLO 모델과, OCR(Optical Character Recognition) 모델, 및 BERT 모델을 포함하는 다중 모달 분석(Multi-modal Analysis) 기술을 이용하고,상기 제2 인공지능 모델에, 상기 광고 상품의 정보를 입력하여 상기 광고 상품의 정보를 기반으로 하는 새로운 광고 콘텐츠를 생성하고,상기 제3 인공지능 모델에, 상기 광고 상품의 정보를 입력하여 상기 광고 상품의 정보를 기반으로 하는 새로운 랜딩 페이지를 생성하고,상기 광고 추천부는,상기 광고주 단말에, 상기 데이터 분석부가 시각화한 시간대별, 요일별, 월별 예상 노출수 및 상기 시간대별 예상 CPA와, 상기 제2 인공지능 모델에서 생성한 상기 광고 상품의 정보를 기반으로 하는 새로운 광고 콘텐츠와, 상기 제3 인공지능 모델에서 생성한 상기 광고 상품의 정보를 기반으로 하는 새로운 랜딩 페이지를 전송하는, 시스템.",
#         "application_date": "20230329",
#         "register_number": "2559950",
#         "documentId": "kr20230041575b1",
#         "application_number": "2023-0041575"
#     }
# ```

# %%
total_content = []

for raw_dataset in raw_dataset_list:
    raw_data = raw_dataset["dataset"]
    data_id = raw_data["documentId"]
    for label_dataset in label_dataset_list:
        label_data = label_dataset["dataset"]
        # 같은 문서가 아니면 건너뛰기
        if data_id != label_data["documentId"]:
            continue
        
        # 같은 문서일 경우 base 형식으로 만들기
        base_data = base_format.copy()

        if raw_data.get("register_date", None):
            base_data["register_year"] = raw_data["register_date"][:4]
            base_data["register_month"] = raw_data["register_date"][4:6]
            base_data["register_day"] = raw_data["register_date"][6:]
        
        base_data["register_number"] = raw_data.get("register_number", None)

        if raw_data.get("application_date", None):
            base_data["application_year"] = raw_data["application_date"][:4]
            base_data["application_month"] = raw_data["application_date"][4:6]
            base_data["application_day"] = raw_data["application_date"][6:]

        base_data["application_number"] = raw_data.get("application_number", None)

        if raw_data.get("open_date", None):
            base_data["open_year"] = raw_data["open_date"][:4]
            base_data["open_month"] = raw_data["open_date"][4:6]
            base_data["open_day"] = raw_data["open_date"][6:]

        base_data["open_number"] = raw_data.get("open_number", None)
        

        base_data["ipc_all"] = raw_data.get("ipc_all", None)
        if not base_data["ipc_all"]:
            base_data["ipc_section"] = raw_data.get("ipc_section", None)
            base_data["ipc_class"] = raw_data.get("ipc_class", None)
            base_data["ipc_subclass"] = raw_data.get("ipc_subclass", None)
            base_data["ipc_maingroup"] = raw_data.get("ipc_main", None)

        base_data["large_no"] = label_data.get("Lno", None)
        base_data["middle_no"] = label_data.get("Mno", None)
        base_data["small_no"] = label_data.get("Sno", None)

        base_data["country_code"] = label_data.get("country_code", None)
        base_data["document_id"] = raw_data.get("documentId", None)
        base_data["document_type"] = label_data.get("document_type", None)
        
        base_data["invention_title"] = raw_data.get("invention_title", None)
        base_data["inventor_name"] = raw_data.get("inventor_name", None)
        base_data["applicant_name"] = raw_data.get("applicant_name", None)
        base_data["claims"] = raw_data.get("claims", None)
        base_data["abstract"] = raw_data.get("abstract", None)
        base_data["keyword"] = label_data.get("keyword", None).split("/")

        base_data["invention_info"] = \
        f'[발명의 명칭] {base_data["invention_title"]}' + "/n" + f'[발명자명] {base_data["inventor_name"]}' + '/n' + \
        f'[출원인명] {base_data["applicant_name"]}' + '/n' + '[청구항]' + '/n' + f'{base_data["claims"]}' + '/n' + \
        f'[요약] {base_data["abstract"]}' + '/n' + f'[주요 키워드] {", ".join(base_data["keyword"])}'

        base_data = json.load


    total_content.append(base_data)

# %%
# json 저장
embedding_data_path = os.path.join(dataset_path, "for_embedding.json")
total_json = json.dumps(total_content, indent=4, ensure_ascii=False)
with open(embedding_data_path, "w", encoding="utf-8") as f:
    f.write(total_json)

# %%
# 임베딩용으로 변환하기
from langchain.embeddings import SentenceTransformerEmbeddings

model_name = "dragonkue/BGE-m3-ko"    # 작은 모델(0.6B)
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}
embedding = SentenceTransformerEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

# %%
total_content[0]
# Out:
# {'register_year': None,
#  'register_month': None,
#  'register_day': None,
#  'regitster_number': None,
#  'application_year': '2002',
#  'application_month': '03',
#  'application_day': '25',
#  'application_number': '2002-578212',
#  'open_year': None,
#  'open_month': None,
#  'open_day': None,
#  'open_number': None,
#  'ipc_all': 'G06N-005/04',
#  'ipc_section': None,
#  'ipc_class': None,
#  'ipc_subclass': None,
#  'ipc_maingroup': None,
#  'large_no': 'C',
#  'middle_no': 'CC',
#  'small_no': 'CCC',
#  'country_code': 'JP',
#  'document_id': 'jp2002578212a',
#  'document_type': 'A',
#  'invention_title': '인공지능 애플리케이션을 위한 음례를 선택하는 적응형 샘플링 수법',
#  'inventor_name': None,
#  'applicant_name': '코닌크렉카 필립스 엘렉트로닉스 N 비',
#  'claims': '정례 및 음례를 가지는 훈련 세트한 이용을 필요로 하는 인공지능 애플리케이션을 실행하도록 구성된 처리 장치로서,데이터 및/또는 명령을 저장하도록 구성된 적어도 1개의 메모리와,상기 적어도 1개의 메모리를 이용하여, 훈련을 위한 정례 세트를 인식해 유지하는 조작, 및 상기 정례 세트에 따라 훈련을 위한 음례 세트를 선택하는 조작을 실행하도록 구성된 적어도 1개의 프로세서와,를 가지는 처리 장치.정례 및 음례를 가지는 훈련 세트한 이용을 필요로 하는, 콘텐츠를 추천하는 방법으로서,훈련을 위한 정례 세트를 인식해 유지하는 단계와,상기 정례 세트에 따라 훈련을 위한 음례 세트를 선택하는 단계와,를 가지는 방법.컴퓨터 프로그램으로서, 상기 컴퓨터 프로그램을 실행했을 때에, 프로그램 가능인 기기가 청구항 1 내지 8의 어느 한 항에 기재된 장치로서 기능하는 것을 가능하게 하는 컴퓨터 프로그램.',
#  'abstract': '인공지능 애플리케이션은 정례 및 음례를 포함한 훈련 세트한 이용을 필요로 한다. 음례는 특징 공간에서 우위인 특징에 관해서 정례의 분포를 이용하여 선택된다. 음례는 특징 공간에서 우위인 특징의 값을 상기 정례와 공유하는 또는 대략 공유한다. 이 타입의 훈련 세트가, 콘텐트리코멘다, 특히 텔레비젼 프로그램에 대한 리코멘다에 관해서 설명된다.',
#  'keyword': ['인공지능', '특징', '공유', '훈련', '프로그램', '로그', '인공지능'],
#  'invention_info': '[발명의 명칭] 인공지능 애플리케이션을 위한 음례를 선택하는 적응형 샘플링 수법/n[발명자명] None/n[출원인명] 코닌크렉카 필립스 엘렉트로닉스 N 비/n[청구항]/n정례 및 음례를 가지는 훈련 세트한 이용을 필요로 하는 인공지능 애플리케이션을 실행하도록 구성된 처리 장치로서,데이터 및/또는 명령을 저장하도록 구성된 적어도 1개의 메모리와,상기 적어도 1개의 메모리를 이용하여, 훈련을 위한 정례 세트를 인식해 유지하는 조작, 및 상기 정례 세트에 따라 훈련을 위한 음례 세트를 선택하는 조작을 실행하도록 구성된 적어도 1개의 프로세서와,를 가지는 처리 장치.정례 및 음례를 가지는 훈련 세트한 이용을 필요로 하는, 콘텐츠를 추천하는 방법으로서,훈련을 위한 정례 세트를 인식해 유지하는 단계와,상기 정례 세트에 따라 훈련을 위한 음례 세트를 선택하는 단계와,를 가지는 방법.컴퓨터 프로그램으로서, 상기 컴퓨터 프로그램을 실행했을 때에, 프로그램 가능인 기기가 청구항 1 내지 8의 어느 한 항에 기재된 장치로서 기능하는 것을 가능하게 하는 컴퓨터 프로그램./n[요약] 인공지능 애플리케이션은 정례 및 음례를 포함한 훈련 세트한 이용을 필요로 한다. 음례는 특징 공간에서 우위인 특징에 관해서 정례의 분포를 이용하여 선택된다. 음례는 특징 공간에서 우위인 특징의 값을 상기 정례와 공유하는 또는 대략 공유한다. 이 타입의 훈련 세트가, 콘텐트리코멘다, 특히 텔레비젼 프로그램에 대한 리코멘다에 관해서 설명된다./n[주요 키워드] 인공지능, 특징, 공유, 훈련, 프로그램, 로그, 인공지능',
#  'register_number': None}

# %%
# 임베딩용 키-값 Document에 저장하기

from langchain_core.documents import Document

documents = []

for content in total_content:
    document = Document(
        page_content=content["invention_info"],
        metadata={
            "document_id": content["document_id"],
            "document_type": content["document_id"],
            "country_code": content["country_code"],
            "large_code": content["large_no"],
            "middle_code": content["middle_no"],
            "small_code": content["small_no"],
            # 출원 관련
            "application_number": content["application_number"],
            "application_year": content["application_year"],
            "application_month": content["application_month"],
            "application_day": content["application_day"],
            # 등록 관련
            "regitster_number": content["regitster_number"],
            "register_year": content["register_year"],
            "register_month": content["register_month"],
            "register_day": content["register_day"],
            # 공개 관련
            "open_number": content["open_number"],
            "open_year": content["open_year"],
            "open_month": content["open_month"],
            "open_day": content["open_day"],
            # ipc 관련
            "ipc_all": content["ipc_all"],
            "ipc_section": content["ipc_section"],
            "ipc_class": content["ipc_class"],
            "ipc_subclass": content["ipc_subclass"],
            "ipc_maingroup": content["ipc_maingroup"] 
        }
    )

    documents.append(document)

print("전체 Docs 개수:", len(documents))
# Out:
# 전체 Docs 개수: 22103

# %% [markdown]
# - pg vector는 postgre를 사용한다고 해서 sql로 데이터 넣어주기
